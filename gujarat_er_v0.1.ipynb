# %%
import cv2
import pdf2image
from PIL import Image
import numpy as np
from pytesseract import pytesseract
import matplotlib as mpl
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual
import pandas as pd
import re

mpl.rcParams['image.cmap'] = 'gray'

path_to_tesseract = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
pytesseract.tesseract_cmd = path_to_tesseract

# %%
start_pdf = 101
end_pdf = 101

# %%
def convert_pdf_to_image(file, dpi):
    images_list = []
    images = pdf2image.convert_from_path(file, dpi = dpi, poppler_path = r"C:\Users\Amandeep Singh\Downloads\Release-23.05.0-0\poppler-23.05.0\Library\bin")
    
    for i, image in enumerate(images):
        image_np = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
        images_list.append(image_np)
        
    return images_list

# %%
def f(x):
    global horizontal_lines_img, verticle_lines_img, kernel
    kernel_length = np.array(img).shape[1]//x

    verticle_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1, kernel_length))
    hori_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (kernel_length, 1))
    
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
    img_temp1 = cv2.erode(img_bin, verticle_kernel, iterations=3)
    verticle_lines_img = cv2.dilate(img_temp1, verticle_kernel, iterations=3)
    
    cv2.imwrite("Images/verticle_lines.jpg",verticle_lines_img)
    img_temp2 = cv2.erode(img_bin, hori_kernel, iterations=3)
    horizontal_lines_img = cv2.dilate(img_temp2, hori_kernel, iterations=3)

# %%
def sort_contours(cnts, method):
    boundingBoxes = [cv2.boundingRect(c) for c in cnts]
    (cnts, boundingBoxes) = zip(*sorted(zip(cnts, boundingBoxes),key=lambda b:[b[1][1],b[1][0]] , reverse=False))
    return (cnts, boundingBoxes)

# %%
for pdf_file in range(start_pdf, end_pdf+1):
    images = convert_pdf_to_image(str(pdf_file)+".pdf", 300)
    
    final_list = []
    count = 0 
    for i in range(2, len(images)-1):
        img = cv2.cvtColor(images[i], cv2.COLOR_BGR2GRAY)
        
        (thresh, img_bin) = cv2.threshold(img, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
        img_bin = 255 - img_bin
        cv2.imwrite("Images/Image_bin.jpg", img_bin)

        interact(f, x = widgets.IntSlider(min = 1, max = 255, step = 1, value = 50));
        
        alpha = 0.5
        beta = 1.0 - alpha
        img_final_bin = cv2.addWeighted(verticle_lines_img, alpha, horizontal_lines_img, beta, 0.0)
        img_final_bin = cv2.erode(~img_final_bin, kernel, iterations=2)
        (thresh, img_final_bin) = cv2.threshold(img_final_bin, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
        
        contours, hierarchy = cv2.findContours(img_final_bin, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        (contours, boundingBoxes) = sort_contours(contours,"top-to-bottom")
        
        g = []
        for c in contours:
            x, y, w, h = cv2.boundingRect(c)
            if(w < 800 and w > 700 and h > 320):
                g.append([x, y, w, h])
                
        a = []
        for i in range(len(g)):
            if i == 0:
                a.append(g[i])
            else:
                if np.abs(g[i][0] - g[i-1][0]) < 50:
                    pass
                else:
                    a.append(g[i])
               
        for i in a:
            new_img = img[i[1]:i[1]+i[3], i[0]:i[0]+i[2]]
            dic = {}
            
            extracted_text = pytesseract.image_to_string(new_img, lang='guj', config='--oem 3 --psm 6')
            extracted_text = extracted_text.split()
            print(extracted_text)
            print("---")
            
            #Getting name from the list
            start_index_for_name = None
            end_index_for_name = None
            for i, item in enumerate(extracted_text):
                if item.endswith("દારનું") or item.endswith("દારનું") or item.startswith("મત્\u200cદારનું"):
                    start_index_for_name = i
                elif (item.startswith("પિતાનું") or item.startswith("પતિનું")) and end_index_for_name is None:
                    end_index_for_name = i
                    break
            
            dic["Name"] = "Start index is None" if start_index_for_name is None else None
            dic["Name"] = "End index is None" if end_index_for_name is None else None
            
            if start_index_for_name is not None and end_index_for_name is not None:
                name = " ".join(extracted_text[start_index_for_name:end_index_for_name])
                
                pattern = r'[:;]'
                name = re.split(pattern, name, maxsplit = 1)[-1].strip()
                
                dic["Name"] = name
            else:
                dic["Name"] = "None"
                
            #Getting relation
            start_index_for_relation = None
            end_index_for_relation = None
            relation = None
            for i, item in enumerate(extracted_text):
                if item.startswith("પિતાનું") and start_index_for_relation is None:
                    relation = "Father"
                    start_index_for_relation = i
                    break
                elif item.startswith("પતિનું") and start_index_for_relation is None:
                    relation = "Husband"
                    start_index_for_relation = i
                    break
            
            for i, item in enumerate(extracted_text):
                if (item.startswith('ઘર') or item.startswith('ઘર')) and end_index_for_relation is None:
                    end_index_for_relation = i
                    break
                    
            if start_index_for_relation is not None and end_index_for_relation is not None:
                    relation_name = " ".join(extracted_text[start_index_for_relation:end_index_for_relation])
                    
                    pattern = r'[:;]'
                    relation_name = re.split(pattern, relation_name, maxsplit = 1)[-1].strip()
                    relation_name = relation_name.split()
                    relation_name = ' '.join(relation_name[:2])
                    
            if relation == "Father":
                dic["FatherName"] = relation_name
            else:
                dic["FatherName"] = ""
                
            if relation == "Husband":
                dic["HusbandName"] = relation_name
            else:
                dic["HusbandName"] = ""
                
            dic["num"] = count
            
            print(dic)
            final_list.append(dic)
            print("===")
            count += 1
            
    sd = pd.DataFrame(final_list)
    sd[["Name", "FatherName", "HusbandName"]].to_excel(str(pdf_file) + ".xlsx")
    
    print(f"{pdf_file} completed")
    
print("===")
print("end")
# Out:
# interactive(children=(IntSlider(value=50, description='x', max=255, min=1), Output()), _dom_classes=('widget-i…
# ['સા', '12342780', 'મતદારનું', 'નામ', ':', 'રાજેશચંદ્ર', 'સકસેના', 'પિતાનું', 'નામ:', 'અર્જુનસિંઘ', 'સકસેના', 'ઘર', 'નંબર', ':', '5-અ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '59', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'રાજેશચંદ્ર સકસેના', 'FatherName': 'અર્જુનસિંઘ સકસેના', 'HusbandName': '', 'num': 0}
# ===
# ['|', 'થુ', '(12342798', 'મતદારનું', 'નામ', ':', 'કંચનબેન', 'સકસેના', 'પતિનું', 'નાંમ:', 'રાજેશચંદ્ર', 'સકસેના', 'જિમિ', 'ઘર', 'નૅબર', ':', '5-અ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '47', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'કંચનબેન સકસેના', 'FatherName': '', 'HusbandName': 'રાજેશચંદ્ર સકસેના', 'num': 1}
# ===
# ['[|]', '3]', 'ઉ]/04/018/201610', 'મૃતદારનું', 'નામ', ':', 'દીલીપભાઇ', 'ચેટરજી', 'પિતાનું', 'નામ:', 'જગબંધુભાઇ', 'ચેટરજી', 'મે', 'ઘર', 'નંબર', ':', '7', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '59', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'દીલીપભાઇ ચેટરજી', 'FatherName': 'જગબંધુભાઇ ચેટરજી', 'HusbandName': '', 'num': 2}
# ===
# ['[|', '41', 'ઉ]/04/018/201611', 'મતદારનું', 'નામ', ':', 'રીનાબેન', 'ચેટરજી', 'પતિનું', 'નામ:', 'દીલીપભાઇ', 'ચેટરજી', 'ર', 'ઘર', 'નબર', ':', '7', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '55', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'રીનાબેન ચેટરજી', 'FatherName': '', 'HusbandName': 'દીલીપભાઇ ચેટરજી', 'num': 3}
# ===
# ['|]', '5', '6૫૫૮3731692', 'મૃતદારનું', 'નામ', ':', 'દેવાશીશ', 'ચેટરજી', 'પિતાનું', 'નામ:', 'દીલીપભાઇ', 'ચેટરજી', 'ક', 'ઘર', 'નંબર', ':', '7', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '36', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'દેવાશીશ ચેટરજી', 'FatherName': 'દીલીપભાઇ ચેટરજી', 'HusbandName': '', 'num': 4}
# ===
# ['મૃતદારનું', 'નામ', ':', 'સુમન', 'એટી', '.', 'પિતાનું', 'નામ:', 'દિલીપભાઇ', 'ચેટરજી', 'ઘર', 'નંબર', ':', '૭', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '29', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'સુમન એટી .', 'FatherName': 'દિલીપભાઇ ચેટરજી', 'HusbandName': '', 'num': 5}
# ===
# ['૪013366135', 'મત્\u200cદારનું', 'નામ', ':', 'જાની', 'નાઈ', 'પતિનું', 'નામ:', 'મહન્દ્રભાઈ', 'ના', 'ઘર', 'નબર', ':', '10', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '30', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'જાની નાઈ', 'FatherName': '', 'HusbandName': 'મહન્દ્રભાઈ ના', 'num': 6}
# ===
# ['મતદારનું', 'નામ', ':', 'રંજનબેન', 'મકવાણા', 'પતિનું', 'નામ:', 'જયપાલભાઈ', 'મકવાના', 'જ', 'ઘર', 'નંબર', ':', '10', 'બી', 'રૈલર્વૈ', 'લોકો', 'કાલોની', '|', 'શેટો', 'ઉપલબ્ધ', 'ઉમર', ':', '33', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'રંજનબેન મકવાણા', 'FatherName': '', 'HusbandName': 'જયપાલભાઈ મકવાના', 'num': 7}
# ===
# ['મતદારનું', 'નામ', ';', 'શંકરભાઇ', 'રવીદાસ', 'પિતાનું', 'નામ:', 'સીતારામભાઇ', 'રવીદાસ', 'ન', 'ઘર', 'નંબર', ':', '11', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '52', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'શંકરભાઇ રવીદાસ', 'FatherName': 'સીતારામભાઇ રવીદાસ', 'HusbandName': '', 'num': 8}
# ===
# ['૪2343341', 'મતદારનું', 'નામ', ':', 'મનોજભાઇ', 'રવીદાસ', 'પિતાનું', 'નામ:', 'કપીલદેવ', 'રવીદાસ', 'ઘર', 'નંબર', ':', '11', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '49', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'મનોજભાઇ રવીદાસ', 'FatherName': 'કપીલદેવ રવીદાસ', 'HusbandName': '', 'num': 9}
# ===
# ['મતદારનું', 'નામ', ':', 'સંગમીત્રા', 'રવીદાસ', 'પતિનું', 'નામ:', 'શંકરભાઇ', 'રવીદાસ', 'ઘર', 'નંબર', ':', '11', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '47', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'સંગમીત્રા રવીદાસ', 'FatherName': '', 'HusbandName': 'શંકરભાઇ રવીદાસ', 'num': 10}
# ===
# ['|', 'પય', 'નાન', 'મૃતદારનું', 'નામ', ':', 'સ્વેતા', 'મકવાણા', 'પિતાનું', 'નામ:', 'જગદીશભાઈ', 'ઘર', 'નંબર', ':', '૧૭', 'બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '26', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'સ્વેતા મકવાણા', 'FatherName': 'જગદીશભાઈ', 'HusbandName': '', 'num': 11}
# ===
# ['મતદારનું', 'નામ', ':', 'હીતેન્દ્રભાઇ', 'વ્યાસ', 'પિતાનું', 'નામ:', 'અનંતરાય', 'વ્યાસ', 'ઘર', 'નંબર', ':', '22', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '53', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'હીતેન્દ્રભાઇ વ્યાસ', 'FatherName': 'અનંતરાય વ્યાસ', 'HusbandName': '', 'num': 12}
# ===
# ['6૫૫૮0765198', 'મતદારનું', 'નામ', ':', 'તેજલબેન', 'વ્યાસ', 'પતિનું', 'નામ:', 'હીતેન્દ્રભાઇ', 'વ્યાસ', 'ઘર', 'નંબર', ':', '22', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '46', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'તેજલબેન વ્યાસ', 'FatherName': '', 'HusbandName': 'હીતેન્દ્રભાઇ વ્યાસ', 'num': 13}
# ===
# ['મ', 'છો', '૯૫૮5272364', 'મતદારનું', 'નામ', ':', 'કનૈયાલાલ', 'ચૌરાસીયા', 'પિતાનું', 'નામ:', 'ખેદનપ્રસાદ', 'ચૌરાસીયા', 'ન', 'ઘર', 'નંબર', ':', '29', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '62', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'કનૈયાલાલ ચૌરાસીયા', 'FatherName': 'ખેદનપ્રસાદ ચૌરાસીયા', 'HusbandName': '', 'num': 14}
# ===
# ['મતદારનું', 'નામ', ';', 'જશોદાબેન', 'ચૌરાસીયા', 'પતિનું', 'નામ:', 'કનૈયાલાલ', 'ચૌરાસીયા', 'ઘર', 'નેંબર', ':', '29', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '57', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'જશોદાબેન ચૌરાસીયા', 'FatherName': '', 'HusbandName': 'કનૈયાલાલ ચૌરાસીયા', 'num': 15}
# ===
# ['૪011656131', 'મતદારનું', 'નામ', ':', 'અજય', 'ચોરસીયા', 'પિતાનું', 'નામ:', 'કનૈયાલાલ', 'ચોરસીયા', 'ઘર', 'નંબર', ':', '29', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '32', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'અજય ચોરસીયા', 'FatherName': 'કનૈયાલાલ ચોરસીયા', 'HusbandName': '', 'num': 16}
# ===
# ['12489177', 'મતદારનું', 'નામ', ':', 'ન', 'નીલકુમાર', 'ચોરસીયા', 'પિતાનું', 'નામ:', 'રાજેન્દ્રપ્રસાદ', 'ચોરસીયા', 'ક', 'ઘર', 'નંબર', ':', 'ર૯', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '29', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'ન નીલકુમાર ચોરસીયા', 'FatherName': 'રાજેન્દ્રપ્રસાદ ચોરસીયા', 'HusbandName': '', 'num': 17}
# ===
# ['12785087', 'મતદારનું', 'નામ', ':', 'અભિશેક', 'ચૌરસીયા', 'પિતાનું', 'નામ:', 'કનૈયાલાલ', 'ચૌરસીયા', 'ઘર', 'નંબર', ':', '૨૯', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '28', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'અભિશેક ચૌરસીયા', 'FatherName': 'કનૈયાલાલ ચૌરસીયા', 'HusbandName': '', 'num': 18}
# ===
# ['68૫૮1699826', 'મતદારનું', 'નામ', ':', 'મધુબેન્\u200c', 'નૈયા', 'પતિનું', 'નામ:', 'હકાભાઇ', 'નૈયા', 'ઘર', 'નંબર', ':', '30', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '52', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'મધુબેન્\u200c નૈયા', 'FatherName': '', 'HusbandName': 'હકાભાઇ નૈયા', 'num': 19}
# ===
# ['મતદારનું', 'નામ', ':', 'નીલેશભાઇ', 'નૈયા', 'પિતાનું', 'નામ:', 'હકાભાઇ', 'નૈયા', 'રી', 'ઘર', 'નંબર', ':', '30', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '35', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'નીલેશભાઇ નૈયા', 'FatherName': 'હકાભાઇ નૈયા', 'HusbandName': '', 'num': 20}
# ===
# ['મૃતદારનું', 'નામ', ':', 'સેજલ', 'નૈયા', 'પિતાનું', 'નામ:', 'હકાભાઇ', 'નૈયા', 'ઘર', 'નંબર', ':', '૩૦', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '33', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'સેજલ નૈયા', 'FatherName': 'હકાભાઇ નૈયા', 'HusbandName': '', 'num': 21}
# ===
# ['[મ', '2]', '12342806', 'મતદારનું', 'નામ', ':', 'અરૂણ', 'નૈયા', 'પિતાનું', 'નામ:', 'હકાભાઇ', 'નૈયા', 'ઘર', 'નંબર', ':', '30', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '31', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'અરૂણ નૈયા', 'FatherName': 'હકાભાઇ નૈયા', 'HusbandName': '', 'num': 22}
# ===
# ['0112785095', 'મૃતદારનું', 'નામ', ':', 'કાજલ', 'નૈયા', 'પિતાનું', 'નામ:', 'હકાભાઇ', 'નૈયા', 'ઘર', 'નંબર', ':', '૩૦', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '30', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'કાજલ નૈયા', 'FatherName': 'હકાભાઇ નૈયા', 'HusbandName': '', 'num': 23}
# ===
# ['[5]', 'લ(04/018/054640', 'મૃતદારનું', 'નામ', ':', 'અરવીંદભાઇ', 'સોલંકી', 'પિતાનું', 'નામ:', 'નાથાલાલ', 'સોલંકી', 'ઘર', 'નંબર', ':', '32', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '64', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'અરવીંદભાઇ સોલંકી', 'FatherName': 'નાથાલાલ સોલંકી', 'HusbandName': '', 'num': 24}
# ===
# ['મૃતદારનું', 'નામ', ':', 'મહેશભાઇ', 'સોલંકી', 'પિતાનું', 'નામ:', 'અરવિંદભાઈ', 'સોલંકી', 'ઘર', 'નંબર', ':', '૩૨', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '36', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'મહેશભાઇ સોલંકી', 'FatherName': 'અરવિંદભાઈ સોલંકી', 'HusbandName': '', 'num': 25}
# ===
# ['ઊ1/04/018/054641', 'મતદારનું', 'નામ', ':', 'સુમીગ્રાબેન', 'સોલંકી', 'પતિનું', 'નામ:', 'અરવોંદભાઇ', 'સોલંકી', 'કિ', 'ઘર', 'નૅબર', ':', '32', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '61', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'સુમીગ્રાબેન સોલંકી', 'FatherName': '', 'HusbandName': 'અરવોંદભાઇ સોલંકી', 'num': 26}
# ===
# ['0012785129', 'મતદારનું', 'નામ', ':', 'વિલાશબેન', 'સોલંકી', 'પતિનું', 'નામ:', 'મહેશભાઇ', 'સોલંકી', 'ઘર', 'નંબર', ':', '૩૨', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '34', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'વિલાશબેન સોલંકી', 'FatherName': '', 'HusbandName': 'મહેશભાઇ સોલંકી', 'num': 27}
# ===
# ['૯1૫૮2286656', 'મતદારનું', 'નામ', ':', 'રંભાબેન', 'મીયાવડા', 'પતિનું', 'નામ:', 'ધીરૂભાઇ', 'મીયાવડા', 'ઘર', 'નબર', ':', '37', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '64', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'રંભાબેન મીયાવડા', 'FatherName': '', 'HusbandName': 'ધીરૂભાઇ મીયાવડા', 'num': 28}
# ===
# ['મતદારનું', 'નામ', ';', 'ભરતભાઇ', 'મીયાવડા', 'પિતાનું', 'નામ:', 'ધીરૂભાઇ', 'મીયાવડા', 'ન', 'ઘર', 'નંબર', ':', '37', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '47', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'ભરતભાઇ મીયાવડા', 'FatherName': 'ધીરૂભાઇ મીયાવડા', 'HusbandName': '', 'num': 29}
# ===
# interactive(children=(IntSlider(value=50, description='x', max=255, min=1), Output()), _dom_classes=('widget-i…
# ['મતદારનું', 'નામ', ':', 'સરોજબેન', 'મીયાવડા', 'પતિનું', 'નાંમ:', 'ભરતભાઇ', 'મીયાવડા', 'ઘર', 'નેંબર', ':', '37', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '44', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'સરોજબેન મીયાવડા', 'FatherName': '', 'HusbandName': 'ભરતભાઇ મીયાવડા', 'num': 30}
# ===
# ['મૃતદારનું', 'નામ', ';', 'બહાડરમાઇ', 'મીયાવડા', 'પિતાનું', 'નામ:', 'ધીરૂભાઈ', 'મીયાવડા', 'મિ', 'ઘર', 'નંબર', ':', '37', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '42', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'બહાડરમાઇ મીયાવડા', 'FatherName': 'ધીરૂભાઈ મીયાવડા', 'HusbandName': '', 'num': 31}
# ===
# ['મતદારનું', 'નામ', ':', 'મીનાબેન', 'મીયાવડા', 'પતિનું', 'નામ:', 'બહાદુરભાઇ', 'મીયાવડા', 'સિ', 'ઘર', 'નૅબર', ':', '37', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '39', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'મીનાબેન મીયાવડા', 'FatherName': '', 'HusbandName': 'બહાદુરભાઇ મીયાવડા', 'num': 32}
# ===
# ['|]', '૩]', 'ઊ[/06/042/292103', 'મૃતદારનું', 'નામ', ':', 'લલીતભાઇ', 'બગડા', 'પિતાનું', 'નામ:', 'દેસાભાઇ', 'બગડા', 'ર', 'ઘર', 'નંબર', ':', '40', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '52', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'લલીતભાઇ બગડા', 'FatherName': 'દેસાભાઇ બગડા', 'HusbandName': '', 'num': 33}
# ===
# [']', '35]', 'ઊ1/06/042/292107', 'મતદારનું', 'નામ', ':', 'નયનાબેન', 'બગડા', 'પતિનું', 'નામ:', 'લલીતભાઇ', 'બગડા', '%', 'ઘર', 'નંબર', ':', '40', 'ફોટો', 'ઉપલબ્ય', 'ઉમર', ':', '49', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'નયનાબેન બગડા', 'FatherName': '', 'HusbandName': 'લલીતભાઇ બગડા', 'num': 34}
# ===
# ['મૃતદારનું', 'નામ', ':', 'હીના', 'લલીતભાર્\u200cઈ', 'બગડા', 'પિતાનું', 'નામ:', 'લલીતભાઈ', 'બગડા', 'ઘર', 'નંબર', ':', '૪૦', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '29', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'હીના લલીતભાર્\u200cઈ બગડા', 'FatherName': 'લલીતભાઈ બગડા', 'HusbandName': '', 'num': 35}
# ===
# ['મતદારનું', 'નામ', ':', 'કાજલ', 'બગડા', 'પિતાનું', 'નામ:', 'લલીતભાઈ', 'બગડા', 'ઘર', 'નંબર', ':', '૪૦', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '27', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'કાજલ બગડા', 'FatherName': 'લલીતભાઈ બગડા', 'HusbandName': '', 'num': 36}
# ===
# ['મતદારનું', 'નામ', ':', 'જગદીશભાઇ', 'સોલંકી', 'પિતાનું', 'નામ:', 'રામજીભાઇ', 'સોલંકી', 'ઘર', 'નંબર', ':', '42', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '42', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'જગદીશભાઇ સોલંકી', 'FatherName': 'રામજીભાઇ સોલંકી', 'HusbandName': '', 'num': 37}
# ===
# ['(01116540', 'મતદારનું', 'નામ', ':', 'ઈન્દુબેન', 'સોલંકી', 'પતિનું', 'નામ:', 'જગદીશભાઇ', 'સોલંકી', 'ર', 'ઘર', 'નૅબર', ':', '42', 'ફોટો', 'ઉપવબ્લ', 'ઉમર', ':', '40', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'ઈન્દુબેન સોલંકી', 'FatherName': '', 'HusbandName': 'જગદીશભાઇ સોલંકી', 'num': 38}
# ===
# ['02940153', 'પતદાસનું', 'નામ', 'પહ્માબેન', 'ક્યા', 'પેતાનું', 'નામ:', 'ભીમજીભાઇ', 'ખેરૈયા', 'ઘર', 'નંબર', ':46', 'સી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '60', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'None', 'FatherName': '', 'HusbandName': '', 'num': 39}
# ===
# ['ઇહ', 'મતદારનું', 'નામ', ':', 'ખોડુભાઇ', 'ખેરૈયા', 'પિતાનું', 'નામ:', 'ભીમજીભાઇ', 'ખેરૈયા', 'ઘર', 'નંબર', ':', '46', 'સી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '55', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'ખોડુભાઇ ખેરૈયા', 'FatherName': 'ભીમજીભાઇ ખેરૈયા', 'HusbandName': '', 'num': 40}
# ===
# ['ણ]', '૦4800713', 'મૃતદારનું', 'નામ', ':', 'છગનલાલ', 'પારખી', 'પિતાનું', 'નામ:', 'કાળાભાઇ', 'પારખી', 'ઘર', 'નંબર', ':', '46', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '79', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'છગનલાલ પારખી', 'FatherName': 'કાળાભાઇ પારખી', 'HusbandName': '', 'num': 41}
# ===
# ['મતદારનું', 'નામ', ':', 'શાંતાબેન', 'પારખી', 'પતિનું', 'નામ:', 'છગનભાઇ', 'પારખી', 'ઘર', 'નંબર', ':', '46', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '72', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'શાંતાબેન પારખી', 'FatherName': '', 'HusbandName': 'છગનભાઇ પારખી', 'num': 42}
# ===
# ['6૫૫૯4814216', 'મતદારનું', 'નામ', ':', 'નીલકંઠરાય', 'પારખી', 'પિતાનું', 'નામ:', 'છગનલાલ', 'પારખી', 'ઘર', 'નબર', ':', '46', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '43', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'નીલકંઠરાય પારખી', 'FatherName': 'છગનલાલ પારખી', 'HusbandName': '', 'num': 43}
# ===
# ['6૫64808754', 'મતદારનું', 'નામ', ':', 'ચંદ્રશેપપર', 'પારખી', 'પિતાનું', 'નામ:', 'છગનભાઇ', 'પારખી', 'ન', 'ઘર', 'નંબર', ':', '46', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '39', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'ચંદ્રશેપપર પારખી', 'FatherName': 'છગનભાઇ પારખી', 'HusbandName': '', 'num': 44}
# ===
# ['10500009', 'મતદારનું', 'નામ', ':', 'વનીતાબેન', 'પારખી', 'પતિનું', 'નામ:', 'નિલકંઠસિંહ', 'પારખી', 'ઘર', 'નંબર', ':', '46', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '36', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'વનીતાબેન પારખી', 'FatherName': '', 'HusbandName': 'નિલકંઠસિંહ પારખી', 'num': 45}
# ===
# ['મતદારનું', 'નામ', ':', 'કાલીદાસ', 'ચાવડા', 'પિતાનું', 'નામ:', 'કાનજીભાઇ', 'ચાવડા', 'ઘર', 'નંબર', ':', '53', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '63', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'કાલીદાસ ચાવડા', 'FatherName': 'કાનજીભાઇ ચાવડા', 'HusbandName': '', 'num': 46}
# ===
# ['મતદારનું', 'નામ', ':', 'નીર્મલાબેન', 'ચાવડા', 'પતિનું', 'નામ:', 'કાલીદાસ', 'ચાવડા', 'ક', 'ઘર', 'નંબર', ':', '53', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '59', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'નીર્મલાબેન ચાવડા', 'FatherName': '', 'HusbandName': 'કાલીદાસ ચાવડા', 'num': 47}
# ===
# ['1656156', 'મતદારનું', 'નામ', ':', 'સંજય', 'ચાવડા', 'પિતાનું', 'નામ:', 'કાલિદાસ', 'ચાવડા', 'ઘર', 'નંબર', ':', '53', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '40', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'સંજય ચાવડા', 'FatherName': 'કાલિદાસ ચાવડા', 'HusbandName': '', 'num': 48}
# ===
# ['૪011656149', 'મતદારનું', 'નામ', ':', 'સુંનિલકુમાર', 'ચાવડા', 'પિતાનું', 'નામ:', 'કાલિદાસ', 'ચાવડા', 'ઘર', 'નબર', ':', '53', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '32', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'સુંનિલકુમાર ચાવડા', 'FatherName': 'કાલિદાસ ચાવડા', 'HusbandName': '', 'num': 49}
# ===
# ['ક]', '13868601', 'મતદારનું', 'નામ', ':', 'આરતી', 'આદિદ્રવીડ', 'પતિનું', 'નામ:', 'ભાકેરજ', 'પેડી', 'ઘર', 'નબર', ':', '57બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '32', 'જાતે', ':', 'સ્ત્રી']
# ---
# {'Name': 'આરતી આદિદ્રવીડ', 'FatherName': '', 'HusbandName': 'ભાકેરજ પેડી', 'num': 50}
# ===
# ['[મ', '52]', '૪3868809', 'મૃતદારનું', 'નામ', ':', 'ભાકેરજ', 'અદિદ્રાવીડ', 'પિતાનું', 'નામ:', 'સેગર', 'નટરાજન', 'ઘર', 'નંબર', ':', 'હિ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '38', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'ભાકેરજ અદિદ્રાવીડ', 'FatherName': 'સેગર નટરાજન', 'HusbandName': '', 'num': 51}
# ===
# ['[|]', '53]', 'ઊ]/04/018/069300', 'મતદારનું', 'નામ', ':', 'વીજયકુમાર', 'ચૌઘરી', 'પિતાનું', 'નામ:', 'છોટુરામ', 'ચૌધરી', 'ઘર', 'નબર', ':', '62', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '58', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'વીજયકુમાર ચૌઘરી', 'FatherName': 'છોટુરામ ચૌધરી', 'HusbandName': '', 'num': 52}
# ===
# ['|]', 'ક્ર', 'ઊ|/04/018/069305', 'મતદારનું', 'નામ', ':', 'ચંદાદેવી', 'ચૌધરી', 'પતિનું', 'નામ:', 'વીજયકુમાર', 'ચૌધરી', 'ક', 'ઘર', 'નબર', ':', '62', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '54', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'ચંદાદેવી ચૌધરી', 'FatherName': '', 'HusbandName': 'વીજયકુમાર ચૌધરી', 'num': 53}
# ===
# ['[મ', 'ક', '12427268', 'મંતદારનું', 'નામ', 'પ', 'અકીતા', 'ચૌધરી,', 'પિતાનું', 'નામ:', 'વિજયકુમાર', 'ચૌધર્ર', 'ઘર', 'નંબર', ':', '2', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '30', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'મંતદારનું નામ પ અકીતા ચૌધરી,', 'FatherName': 'વિજયકુમાર ચૌધર્ર', 'HusbandName': '', 'num': 54}
# ===
# ['1013348349', 'મૃતદારનું', 'નામ', ':', 'યુનુસખાન', 'મહેરનાણી', 'પિતાનું', 'નામ:', 'જીવણખાન', 'મહેરનાર્ણ', 'ઘર', 'નંબર', ':', '64', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '64', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'યુનુસખાન મહેરનાણી', 'FatherName': 'જીવણખાન મહેરનાર્ણ', 'HusbandName': '', 'num': 55}
# ===
# ['0112680809', 'મૃતદારનું', 'નામ', ':', 'મિશાલ', 'ચૌધરી', 'પિતાનું', 'નામ:', 'વિજયકુમાર', 'ચૌધરી', 'પિ', 'ઘર', 'નંબર', ':', '62', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '28', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'મિશાલ ચૌધરી', 'FatherName': 'વિજયકુમાર ચૌધરી', 'HusbandName': '', 'num': 56}
# ===
# ['૪013348471', 'મતદારનું', 'નામ', ':', 'હસીનાબેન', 'મહેરનાણી', 'પતિનું', 'નામ:', 'ણ', 'મહેરનાણી', 'ઘર', 'નૅબર', ':', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '61', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'હસીનાબેન મહેરનાણી', 'FatherName': '', 'HusbandName': 'ણ મહેરનાણી', 'num': 57}
# ===
# ['મતદારનું', 'નામ', ':', 'જાવેદખાન', 'મહેરનાણી', 'પિતાનું', 'સાભ:', 'મૂગુસખાન', 'મહેરનાણી', 'ક', 'ઘર', 'નંબર', ':', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '37', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'જાવેદખાન મહેરનાણી', 'FatherName': 'મૂગુસખાન મહેરનાણી', 'HusbandName': '', 'num': 58}
# ===
# ['મતદારનું', 'નામ', ':', 'અહમદભાઇ', 'બ્લોચ', 'પિતાનું', 'નામ:', 'દાદમહમદભાઇ', 'બ્લોચ', 'ન', 'ઘર', 'નંબર', ':', '65', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '57', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'અહમદભાઇ બ્લોચ', 'FatherName': 'દાદમહમદભાઇ બ્લોચ', 'HusbandName': '', 'num': 59}
# ===
# interactive(children=(IntSlider(value=50, description='x', max=255, min=1), Output()), _dom_classes=('widget-i…
# ['6૫૮4908984', 'મતદારનું', 'નામ', ':', 'રસીદાબેન', 'બ્લોચ', 'પતિનું', 'નાંમ:', 'અહમદભાઇ', 'બ્લોચ', 'ઘર', 'નંબર', ':', '65', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '52', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'રસીદાબેન બ્લોચ', 'FatherName': '', 'HusbandName': 'અહમદભાઇ બ્લોચ', 'num': 60}
# ===
# ['મૃતદારનું', 'નામ', ':', 'આમીર', 'બ્લોચ', 'પિતાનું', 'નામ:', 'એહમદભાઈ', 'બ્લોચ', '%', 'ઘર', 'નંબર', ':', '65', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '31', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'આમીર બ્લોચ', 'FatherName': 'એહમદભાઈ બ્લોચ', 'HusbandName': '', 'num': 61}
# ===
# ['મતદારનું', 'નામ', ':', 'અરૂણભાઇ', 'ગોંડલીયા', 'પિતાનું', 'નામ:', 'મગનભાઇ', 'ગોંડલીયા', 'બિ', 'ઘર', 'નંબર', ':', '66', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '65', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'અરૂણભાઇ ગોંડલીયા', 'FatherName': 'મગનભાઇ ગોંડલીયા', 'HusbandName': '', 'num': 62}
# ===
# ['મતદારનું', 'નામ', ':', 'બતુલબાન', 'પઠાણ', 'પતિનું', 'નામ:', 'દીલાવરખાન', 'પઠાણ', 'ર', 'ઘર', 'નંબર', ':', '67', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '52', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'બતુલબાન પઠાણ', 'FatherName': '', 'HusbandName': 'દીલાવરખાન પઠાણ', 'num': 63}
# ===
# ['મતદારનું', 'નામ', ':', 'અફઝલખાન', 'પઠાણ', 'પિતાનું', 'નામ:', 'દીલાવરખાન', 'પઠાણ', 'ઘર', 'નંબર', ':', '67', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '37', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'અફઝલખાન પઠાણ', 'FatherName': 'દીલાવરખાન પઠાણ', 'HusbandName': '', 'num': 64}
# ===
# ['૪૫12342855', 'મૃતદારનું', 'નામ', ':', 'ઇન્તીયાઝખાન', 'પઠાણ', 'પિતાનું', 'નામ:', 'દીલાવરખાન', 'પઠાણ', 'ન', 'ઘર', 'નંબર', ':', '67', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '33', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'ઇન્તીયાઝખાન પઠાણ', 'FatherName': 'દીલાવરખાન પઠાણ', 'HusbandName': '', 'num': 65}
# ===
# ['૯૫૯1958941', 'મતદારનું', 'નામ', ':', 'હંસાબેન', 'જોગડીયા', 'પતિનું', 'નામ:', 'મનજીભાઇ', 'જોગડીયા', 'ઘર', 'નૅબર', ':', '70', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '55', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'હંસાબેન જોગડીયા', 'FatherName': '', 'HusbandName': 'મનજીભાઇ જોગડીયા', 'num': 66}
# ===
# ['6૫૫૯4818522', 'મતદારનું', 'નામ', ':', 'નલીનભાઇ', 'જોગડીયા', 'પિતાનું', 'નામ:', 'મનજીભાઇ', 'જોગડીયા', 'ક', 'ઘર', 'નંબર', ':', '70', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '37', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'નલીનભાઇ જોગડીયા', 'FatherName': 'મનજીભાઇ જોગડીયા', 'HusbandName': '', 'num': 67}
# ===
# ['0012785160', 'મતદારનું', 'નામ', ':', 'ભાવનાબેન', 'જોગડીયા', 'પતિનું', 'નામ:', 'નલીનભાઈ', 'જોગડીયા', 'ર', 'ઘર', 'નબર', ':', '70', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '35', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'ભાવનાબેન જોગડીયા', 'FatherName': '', 'HusbandName': 'નલીનભાઈ જોગડીયા', 'num': 68}
# ===
# ['૯૫૮4856597', 'મતદારનું', 'નામ', ':', 'પીન્કીબેન', 'પરમાર', 'પતિનું', 'નામ:', 'વજુભાઇ', 'પરમાર', 'ઘર', 'નંબર', ':', '71', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '57', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'પીન્કીબેન પરમાર', 'FatherName': '', 'HusbandName': 'વજુભાઇ પરમાર', 'num': 69}
# ===
# ['મતદારનું', 'નામ', ':', 'લલુભાઇ', 'પરમાર', 'પિતાનું', 'નામ:', 'વજુભાઇ', 'પરમાર', 'ઘર', 'નંબર', ':', '71', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '38', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'લલુભાઇ પરમાર', 'FatherName': 'વજુભાઇ પરમાર', 'HusbandName': '', 'num': 70}
# ===
# ['0૫12076636', 'મતદારનું', 'નામ', ':', 'પાર્લી', 'પરમાર', 'પતિનું', 'નામ:', 'લલુભાઇ', 'પરમાર', 'ઘર', 'નબર', ':', '71', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '36', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'પાર્લી પરમાર', 'FatherName': '', 'HusbandName': 'લલુભાઇ પરમાર', 'num': 71}
# ===
# ['મતદારનું', 'નામ', ':', 'કુવરબેન', 'ગરીયા', 'પતિનું', 'નામ:', 'ગોકળભાઇ', 'ગરીયા', 'ઘર', 'નંબર', ':', '72', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '67', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'કુવરબેન ગરીયા', 'FatherName': '', 'HusbandName': 'ગોકળભાઇ ગરીયા', 'num': 72}
# ===
# ['મતદારનું', 'નામ', ':', 'ભાવેશભાઇ', 'ગરીયા', 'પિતાનું', 'નામ:', 'ગોકળભાઇ', 'ગરીયા', 'ઘર', 'નંબર', ':', '72', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '45', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'ભાવેશભાઇ ગરીયા', 'FatherName': 'ગોકળભાઇ ગરીયા', 'HusbandName': '', 'num': 73}
# ===
# ['10839522', 'મતદારનું', 'નામ', ':', 'મનીમેઘલાઈ', 'આદીતરવડે', 'પતિનું', 'નામ:', 'માયેવલ', 'આદીતરવડે', 'ન', 'ઘર', 'નૅબર', ':', '73', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '64', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'મનીમેઘલાઈ આદીતરવડે', 'FatherName': '', 'HusbandName': 'માયેવલ આદીતરવડે', 'num': 74}
# ===
# ['0110839282', 'મૃતદારનું', 'નામ', ':', 'માયાવતી', 'માસી', 'પિતાનું', 'નામ:', 'માયેવલ', 'મદ્રાઃ', 'ઘર', 'નંબર', ':', '73', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '35', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'માયાવતી માસી', 'FatherName': 'માયેવલ મદ્રાઃ', 'HusbandName': '', 'num': 75}
# ===
# ['૪૫013471810', 'મૂતદારનું', 'નામ', ':', 'અનિલ', 'મિતાણી', 'પિતાનું', 'નામ:', 'ધીરુભાઈ', 'મિતાણી', 'ઘર', 'નંબર', ':', '73', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '27', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'અનિલ મિતાણી', 'FatherName': 'ધીરુભાઈ મિતાણી', 'HusbandName': '', 'num': 76}
# ===
# ['મૂતદારનું', 'નામ', ':', 'ઈકબાલ', 'દલ', 'પિતાનું', 'નામ:', 'સાંસા', 'દલ', 'જ', 'ઘર', 'નંબર', ':', '7', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '57', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'ઈકબાલ દલ', 'FatherName': 'સાંસા દલ', 'HusbandName': '', 'num': 77}
# ===
# ['મતદારનું', 'નામ:', 'રોશનબેન', 'દલ', 'પતિનું', 'નામ:', 'ઈકબાલ', 'દલ', 'ઘર', 'નંબર', ':', '75', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '48', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'રોશનબેન દલ', 'FatherName': '', 'HusbandName': 'ઈકબાલ દલ', 'num': 78}
# ===
# ['૪1010839829', 'મતદારનું', 'નામ', ':', 'ચલંભાબેન', 'મહુસી', 'પતિનું', 'નામ:', 'ગોવીંદભાઇ', 'મદ્રાર્સ', 'ઘર', 'નબર', ':', '77', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '77', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'ચલંભાબેન મહુસી', 'FatherName': '', 'HusbandName': 'ગોવીંદભાઇ મદ્રાર્સ', 'num': 79}
# ===
# ['12342871', 'મૂતદારનું', 'નામ', ';', 'બિરેન્દ્રકુમાર', 'ગોતમ', 'પિતાનું', 'નામ:', 'છેદીલાલ', 'ગોતમ', 'ક', 'ઘર', 'નંબર', ':', '80-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '40', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'બિરેન્દ્રકુમાર ગોતમ', 'FatherName': 'છેદીલાલ ગોતમ', 'HusbandName': '', 'num': 80}
# ===
# ['6૫૮1698406', 'મતદારનું', 'નામ', ':', 'વીનાદેવી', 'પાલ', 'પતિનું', 'નામ:', 'નરેશભાઇ', 'પાલ', 'ઘર', 'નેંબર', ':', '80', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '57', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'વીનાદેવી પાલ', 'FatherName': '', 'HusbandName': 'નરેશભાઇ પાલ', 'num': 81}
# ===
# ['મતદારનું', 'નામ', ':', 'વીજયભાઇ', 'પાલ', 'પિતાનું', 'નામ:', 'બનવારીલાલ', 'પાલ', 'ઘર', 'નંબર', ':', '80', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '49', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'વીજયભાઇ પાલ', 'FatherName': 'બનવારીલાલ પાલ', 'HusbandName': '', 'num': 82}
# ===
# ['13471216', 'મૃતદારનું', 'નામ', ':', 'રાજેશભાઈ', 'કવા', 'પિતાનું', 'નામ:', 'અરજણભાઈ', 'કવા', 'જ', 'ઘર', 'નંબર', ':', '80', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '46', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'રાજેશભાઈ કવા', 'FatherName': 'અરજણભાઈ કવા', 'HusbandName': '', 'num': 83}
# ===
# ['ઊ1/06/042/148310', 'તૂતદારનું', 'નામ', ':', 'નો', 'મકવાણા', 'પિતાનું', 'નામ:', 'ચુનીલાલ', 'મકવાણા', 'ઘર', 'નબર', ':', '8', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '69', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'નો મકવાણા', 'FatherName': 'ચુનીલાલ મકવાણા', 'HusbandName': '', 'num': 84}
# ===
# ['૪012342921', 'મતદારનું', 'નામ', ':', 'સુરેન્દ્રપ્રસાદ', 'કુમાર', 'પિતાનું', 'નામ:', 'બાલમુકુન્દ', 'કુમાર', 'ઘર', 'નંબર', ':', '95-સીં', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '73', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'સુરેન્દ્રપ્રસાદ કુમાર', 'FatherName': 'બાલમુકુન્દ કુમાર', 'HusbandName': '', 'num': 85}
# ===
# ['૫3470895', 'મૃતદારનું', 'નામ', ':', 'મુસ્તાક', 'બેલીમ', 'પિતાનું', 'નામ:', 'મહેબૂબભાઈ', 'બેલીમ', 'ક', 'ઘર', 'નંબર', ':', '90', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '23', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'મુસ્તાક બેલીમ', 'FatherName': 'મહેબૂબભાઈ બેલીમ', 'HusbandName': '', 'num': 86}
# ===
# ['૪012342947', 'મતદારનું', 'નામ', 'રગત્રિવેનદ્ર', 'કુમાર', 'પિતાનું', 'નામ:', 'પ્રસાદ', 'ઘર', 'અધર', 'રડ', 'મ્જ્સૌ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '47', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'મતદારનું નામ રગત્રિવેનદ્ર કુમાર', 'FatherName': 'પ્રસાદ', 'HusbandName': '', 'num': 87}
# ===
# ['મતદારનું', 'નામ', ':', 'પુરીલાલ', 'મીના', 'પિતાનું', 'નામ:', 'નંદલાલ', 'મીના', 'ક', 'ઘર', 'નંબર', ':', '96', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '57', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'પુરીલાલ મીના', 'FatherName': 'નંદલાલ મીના', 'HusbandName': '', 'num': 88}
# ===
# ['૯૫૫૮4827440', 'મતદારનું', 'નામ', ':', 'કલાવંતીબેન', 'મીના', 'પતિનું', 'નામ:', 'પાણા', 'મીના', 'ન', 'ઘર', 'નૅબર', ':', '9', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '52', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'કલાવંતીબેન મીના', 'FatherName': '', 'HusbandName': 'પાણા મીના', 'num': 89}
# ===
# interactive(children=(IntSlider(value=50, description='x', max=255, min=1), Output()), _dom_classes=('widget-i…
# ['મૂતદારનું', 'નામ', ':', 'દેવેન્દ્રકુમાર', 'મીના', 'પિતાનું', 'નામ:', 'પ્રણ', 'મીના', 'ઘર', 'નંબર', ':', '9', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '36', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'દેવેન્દ્રકુમાર મીના', 'FatherName': 'પ્રણ મીના', 'HusbandName': '', 'num': 90}
# ===
# ['૪1656180', 'મૃતદારનું', 'નામ', ':', 'સોહીલ', 'ચૌહાણ', 'પિતાનું', 'નામ:', 'ઈકબાલભાઈ', 'ચૌહાણ', 'મિ', 'ઘર', 'નંબર', ':', '97', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '33', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'સોહીલ ચૌહાણ', 'FatherName': 'ઈકબાલભાઈ ચૌહાણ', 'HusbandName': '', 'num': 91}
# ===
# ['૧૫13471687', 'મતદારનું', 'નામ', ':', 'ખુશ્બુ', 'ચાંડપા', 'પિતાનું', 'નામ:', 'કિશોરભાઈ', 'ચાંડપા', 'બિ', 'ઘર', 'નંબર', ':', '104', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '25', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'ખુશ્બુ ચાંડપા', 'FatherName': 'કિશોરભાઈ ચાંડપા', 'HusbandName': '', 'num': 92}
# ===
# ['૪2489185', 'મતદારનું', 'નામ', ':', 'કનુભાઇ', 'ખાચર', 'પિતાનું', 'નામ:', 'શાંતુભાઇ', 'ખાચર', '.', 'ઘર', 'નંબર', ':', '૧૩ર-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '41', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'કનુભાઇ ખાચર', 'FatherName': 'શાંતુભાઇ ખાચર', 'HusbandName': '', 'num': 93}
# ===
# ['0112228690', 'મૃતદારનું', 'નામ', ':', 'સંતોષકુમાર', 'શર્મા', 'પિતાનું', 'નામ:', 'દેવીચરણ', 'શર્મા', 'ઘર', 'નંબર', ':', '133-બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '45', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'સંતોષકુમાર શર્મા', 'FatherName': 'દેવીચરણ શર્મા', 'HusbandName': '', 'num': 94}
# ===
# ['૪૫12489201', 'મતદારનું', 'નામ', ':', 'સુધા', 'શર્મા', 'પતિનું', 'નામ:', 'સંતોલમાર', 'શર્મા', 'ઘર', 'નબર', ':', '૧૩૩-', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '40', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'સુધા શર્મા', 'FatherName': '', 'HusbandName': 'સંતોલમાર શર્મા', 'num': 95}
# ===
# ['૪013471158', 'મત્\u200cદારનું', 'નામ', ':', 'ણન', 'દન', 'કપડવંજી', 'પતિનું', 'નામ:', 'યુનુસભાઈ', 'કપડવંજી', 'ઘર', 'નબર', 'ર', '1', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '49', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'ણન દન કપડવંજી', 'FatherName': '', 'HusbandName': 'યુનુસભાઈ કપડવંજી', 'num': 96}
# ===
# ['01013470945', 'મતદારનું', 'નામ', ':', 'પારસ', 'મનસુહાભાઈ', 'જાદવ', '3', 'પિતાનું', 'નામ:', 'મનસુખાભાઈ', 'જાદવ', 'ફોટો', 'ઉપલબ્ધ', 'ઘર', 'નંબર', ':', '162-બી', 'ઉંમર', ':', '23', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'પારસ મનસુહાભાઈ જાદવ 3', 'FatherName': 'મનસુખાભાઈ જાદવ', 'HusbandName': '', 'num': 97}
# ===
# ['ઊ।/04/018/093281', 'મતદારનું', 'નામ', ':', 'ભિખમ', 'પ્રસાદ', 'પિતાનું', 'નામ:', 'દેઓધારી', 'પ્રસાદ', 'ન', 'ઘર', 'નંબર', ':', '૧૯૦', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '66', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'ભિખમ પ્રસાદ', 'FatherName': 'દેઓધારી પ્રસાદ', 'HusbandName': '', 'num': 98}
# ===
# ['7013470861', 'મતદારનું', 'નામ', ':', 'દિવ્યેશ', 'નરેંદ્રભાઈ', 'ભેડા', 'પિતાનું', 'નામ:', 'નરેદ્ર', 'અમૃતલાલ', 'ભેડા', 'ઘર', 'નંબર', ':', '૧૯૬', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '30', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'દિવ્યેશ નરેંદ્રભાઈ ભેડા', 'FatherName': 'નરેદ્ર અમૃતલાલ', 'HusbandName': '', 'num': 99}
# ===
# ['(03471091', 'મતદારનું', 'નામ', ':', 'સબીના', 'સવાણ', 'પતિનું', 'નામ:', 'ઇન્જામુલ', 'સવાણ', 'ઘર', 'નંબર', ':', '204', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '27', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'સબીના સવાણ', 'FatherName': '', 'HusbandName': 'ઇન્જામુલ સવાણ', 'num': 100}
# ===
# ['01656206', 'મૃતદારનું', 'નામ', ':', 'દેવેન', 'વાળા', 'પિતાનું', 'નામ:', 'કનુભાઈ', 'વાળા', 'ઘર', 'નંબર', ':', 'ટા', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '32', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'દેવેન વાળા', 'FatherName': 'કનુભાઈ વાળા', 'HusbandName': '', 'num': 101}
# ===
# ['13471182', 'મતદારનું', 'નામ', ':', 'મોહસીનભાઈ', 'દોઢિયા', 'પિતાનું', 'નામ:', 'ગફારભાઈ', 'દોઢિયા', 'ધર', 'નંબર', ':', '21', 'રે-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '33', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'મોહસીનભાઈ દોઢિયા', 'FatherName': 'કનુભાઈ વાળા', 'HusbandName': '', 'num': 102}
# ===
# ['13471232', 'મતદારનું', 'નામ', ':', 'હીના', 'હીંગોરા', 'પતિનું', 'નામ:', 'દૂરોનભાઈ', 'હીંગોરા', 'ઘર', 'નંબર', ':', '2', 'દએ', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '27', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'હીના હીંગોરા', 'FatherName': '', 'HusbandName': 'દૂરોનભાઈ હીંગોરા', 'num': 103}
# ===
# ['3471570', 'મતદારનું', 'નામ', ':', 'નયન', 'પ્રવીણભાઈ', 'અમેથીયા', 'ન', 'પિતાનું', 'નામ:', 'પ્રવીણ', 'ભાઈ', 'અમેથીયા', 'ફોટો', 'ઉપલબ્ધ', 'ઘર', 'નંબર', ':', '236', 'ઉમર', ':', '23', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'નયન પ્રવીણભાઈ અમેથીયા ન', 'FatherName': 'પ્રવીણ ભાઈ', 'HusbandName': '', 'num': 104}
# ===
# ['૪૫1૩471620', 'મતદારનું', 'નામ', ':', 'ઉદય', 'ચાવડા', 'પિતાનું', 'નામ:', 'નારણભાઈ', 'ચાવડા', 'ઘર', 'નબર', ':', '262', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '24', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'ઉદય ચાવડા', 'FatherName': 'નારણભાઈ ચાવડા', 'HusbandName': '', 'num': 105}
# ===
# ['૪102785186', 'મતદારનું', 'નામ', ':', 'કીશન', 'સંચાણીયા', 'પિતાનું', 'નામ:', 'અરવિંદભાઇ', 'સંચાણીયા', 'ઘર', 'નબર', ':', '૪૬૩', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '27', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'કીશન સંચાણીયા', 'FatherName': 'અરવિંદભાઇ સંચાણીયા', 'HusbandName': '', 'num': 106}
# ===
# ['(૫3472412', 'મતદારનું', 'નામ', ':', 'સંજય', 'કુમાર', 'નરશીભાઈ', 'ચૌહાણ', 'ક', 'પિતાનું', 'નામ:', 'નરશીભાઈ', 'ચૌહાણ', 'ફોટો', 'ઉપલબ્ધ', 'ઘર', 'નંબર', ':', '૪૯૮', 'ઉમર', ':', '33', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'સંજય કુમાર નરશીભાઈ ચૌહાણ ક', 'FatherName': 'નરશીભાઈ ચૌહાણ', 'HusbandName': '', 'num': 107}
# ===
# ['1૩472024', 'મતદારનું', 'નામ', ':', 'મીતલ', 'મોકાણી', 'પિતાનું', 'નામ:', 'હરજીભાઈ', 'મોકાણી', 'ઘર', 'નંબર', ':', '754', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '32', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'મીતલ મોકાણી', 'FatherName': 'હરજીભાઈ મોકાણી', 'HusbandName': '', 'num': 108}
# ===
# ['૪1013366143', 'મતદારનું', 'નામ', ':', 'દિપેશ', 'કનૌજિયા', 'પિતાનું', 'નામ:', 'રાજકિશોર', 'કનૌજિયા', 'ઘર', 'નંબર', ':', 'બી-૪૧', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '24', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'દિપેશ કનૌજિયા', 'FatherName': 'રાજકિશોર કનૌજિયા', 'HusbandName': '', 'num': 109}
# ===
# ['|]', 'શ1]', '0૫૫૯3734878', 'મૃતદારનું', 'નામ', ':', 'મહેન્દ્રભાઇ', 'નાઈ', 'પિતાનું', 'નામ:', 'રુંમાલાલ', 'નાઈ', 'ક', 'ઘર', 'નંબર', ':', 'સીં-૧૦-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '39', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'મહેન્દ્રભાઇ નાઈ', 'FatherName': 'રુંમાલાલ નાઈ', 'HusbandName': '', 'num': 110}
# ===
# ['[|', '1142]', '૪03074275', 'મૃતદારનું', 'નામ', ':', 'જીતેન્દ્રસિંઘ', 'રાજોરા', 'પિતાનું', 'નામ:', 'સ', 'રાજોરા', 'ઘર', 'નંબર', ':', 'સી-૧૩-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '38', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'જીતેન્દ્રસિંઘ રાજોરા', 'FatherName': 'સ રાજોરા', 'HusbandName': '', 'num': 111}
# ===
# ['[|', '11307]', '૪2129153', 'મતદારનું', 'નામ', ':', 'રેહાનાબેન', 'બ્લોચ', '_', 'પતિનું', 'નામ:', 'મોહમ્મદ', 'અશરફુલ', 'આલોમ', 'ઘર', 'નૅબર', ':', 'સાન', 'એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '34', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'રેહાનાબેન બ્લોચ _', 'FatherName': '', 'HusbandName': 'મોહમ્મદ અશરફુલ', 'num': 112}
# ===
# ['13074283', 'મતદારનું', 'નામ', ':', 'કાનુસિંગ', 'ભાટી', 'પિતાનું', 'નામ:', 'પ્રેમસિંગ', 'ભાટી', 'રો', 'ઘર', 'નંબર', ':', 'સી-૧૬-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '40', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'કાનુસિંગ ભાટી', 'FatherName': 'પ્રેમસિંગ ભાટી', 'HusbandName': '', 'num': 113}
# ===
# ['મૃતદારનું', 'નામ', ':', 'રમેશભાઇ', 'સિતાપરા', 'પિતાનું', 'નામ:', 'સવસીભાઇ', 'સિતાપરા', 'ઘર', 'નંબર', ':', 'સી', '-', '૧૭', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '61', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'રમેશભાઇ સિતાપરા', 'FatherName': 'સવસીભાઇ સિતાપરા', 'HusbandName': '', 'num': 114}
# ===
# ['0113022811', 'મૃતદારનું', 'નામ', ':', 'આશા', 'સિતાપરા', 'પિતાનું', 'નામ:', 'રમેશભાઇ', 'સિતાપરા', 'ઘર', 'નંબર', ':', 'સી', '-', '૧૭', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '28', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'આશા સિતાપરા', 'FatherName': 'રમેશભાઇ સિતાપરા', 'HusbandName': '', 'num': 115}
# ===
# ['મતદારનું', 'નામ', ':', 'સવિતાબેન', 'સિતાપરા', 'અન્ય:', 'રમેશભાઇ', 'સિતાપરા', 'ક', 'ઘર', 'નંબર', ':', 'સી', '-', '૧૭', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '52', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'None', 'FatherName': '', 'HusbandName': '', 'num': 116}
# ===
# ['૪013022845', 'મતદારનું', 'નામ', ':', 'હિતેષ', 'સિતાપરા', 'પિતાનું', 'નામ:', 'રમેશભાઇ', 'સિતાપરા', 'ઘર', 'નંબર', ':', 'સી', '-', '૧૭', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '27', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'હિતેષ સિતાપરા', 'FatherName': 'રમેશભાઇ સિતાપરા', 'HusbandName': '', 'num': 117}
# ===
# ['0012680825', 'મતદારનું', 'નામ', ':', 'જગદીશ', 'મકવાણા', 'પિતાનું', 'નામ:', 'જીવાભાઈ', 'મકવાણા', 'ક', 'ઘર', 'નંબર', ':', 'સી-૧૭-બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '55', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'જગદીશ મકવાણા', 'FatherName': 'જીવાભાઈ મકવાણા', 'HusbandName': '', 'num': 118}
# ===
# ['0012680817', 'મતદારનું', 'નામ', ':', 'ઉષાબેન', 'મકવાણા', 'પતિનું', 'નામ:', 'જગદીશભાઈ', 'મકવાણા', 'ન', 'ઘર', 'નૅબર', ':', 'સી-૧૭-બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '50', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'ઉષાબેન મકવાણા', 'FatherName': '', 'HusbandName': 'જગદીશભાઈ મકવાણા', 'num': 119}
# ===
# interactive(children=(IntSlider(value=50, description='x', max=255, min=1), Output()), _dom_classes=('widget-i…
# ['સા', '12680833', 'મતદારનું', 'નામ', ':', 'રવિકુમાર', 'મકવાણા', 'પિતાનું', 'નામ:', 'જગદીશભાઈ', 'મકવાણા', 'ઘર', 'નંબર', ':', 'સી-૧૭-બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '29', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'રવિકુમાર મકવાણા', 'FatherName': 'જગદીશભાઈ મકવાણા', 'HusbandName': '', 'num': 120}
# ===
# ['મૃતદારનું', 'નામ', ':', 'અરૂણાબેન', 'પંડયા', 'પિતાનું', 'નામ:', 'હરીલાલ', 'પંડયા', 'મિ', 'ઘર', 'નંબર', ':', 'સી-રર', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '49', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'અરૂણાબેન પંડયા', 'FatherName': 'હરીલાલ પંડયા', 'HusbandName': '', 'num': 121}
# ===
# ['મૃતદારનું', 'નામ', ':', 'શીતલ', 'પંડયા', 'પિતાનું', 'નામ:', 'રાજેશકુમાર', 'પંડયા', 'પિ', 'ઘર', 'નંબર', ':', 'સી-રર', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '30', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'શીતલ પંડયા', 'FatherName': 'રાજેશકુમાર પંડયા', 'HusbandName': '', 'num': 122}
# ===
# ['૪013022852', 'મતદારનું', 'નામ', ':', 'ઉર્મિલા', 'સિન્હા', 'પતિનું', 'નામ:', 'નવલકિશોર', 'સિન્હા', 'ઘર', 'નબર', ':', 'સી', '-', 'રર', 'બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '67', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'ઉર્મિલા સિન્હા', 'FatherName': '', 'HusbandName': 'નવલકિશોર સિન્હા', 'num': 123}
# ===
# ['મૃતદારનું', 'નામ', ':', 'સંતોષકુમાર', 'સિન્હા', 'પિતાનું', 'નામ:', 'નવલકિશોરપ્રસાદ', 'સિન્હા', 'ઘર', 'નંબર', ':', 'સી', '-', 'રર', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '39', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'સંતોષકુમાર સિન્હા', 'FatherName': 'નવલકિશોરપ્રસાદ સિન્હા', 'HusbandName': '', 'num': 124}
# ===
# ['૪013022860', 'મતદારનું', 'નામ', ':', 'શિલ્પિ', 'સિન્હા', 'પતિનું', 'નામ:', 'સંતોષકુમાર', 'સિન્હા', 'ઘર', 'નબર', ':', 'સી', '-', 'રર', 'બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '37', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'શિલ્પિ સિન્હા', 'FatherName': '', 'HusbandName': 'સંતોષકુમાર સિન્હા', 'num': 125}
# ===
# ['૪3022886', 'મતદારનું', 'નામ', ':', 'રામચંદ્ર', 'પિતાનું', 'નામ:', 'ભિન્યારામ', 'ઘર', 'નંબર', ':', 'સી', '-', 'રપ', 'બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '35', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'રામચંદ્ર', 'FatherName': 'ભિન્યારામ', 'HusbandName': '', 'num': 126}
# ===
# ['0113022894', 'મતદારનું', 'નામ', ':', 'ફિસેનદુસિંધ', 'રાજવિ', 'પિતાનું', 'નામ:', 'ગોવિંદસિઘ', 'રાજવિ', 'ઘર', 'નંબર', ':', 'સી', '-', 'ર$-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '35', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'ફિસેનદુસિંધ રાજવિ', 'FatherName': 'ગોવિંદસિઘ રાજવિ', 'HusbandName': '', 'num': 127}
# ===
# ['૪1013074291', 'મતદારનું', 'નામ', ':', 'દિપકકુમાર', 'વર્મા', 'પિતાનું', 'નામ:', 'કૃષ્ણ', 'વમ', 'ઘર', 'નંબર', ':', 'સી-૩૪-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '36', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'દિપકકુમાર વર્મા', 'FatherName': 'કૃષ્ણ વમ', 'HusbandName': '', 'num': 128}
# ===
# ['૪012508265', 'મૃતદારનું', 'નામ', ':', 'સૂબાષસિંહ', 'જાધોન', 'પિતાનું', 'નામ:', 'કોકાર્સહ', 'જાધોન', 'ઘર', 'નંબર', ':', 'સી-૩૬-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '46', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'સૂબાષસિંહ જાધોન', 'FatherName': 'કોકાર્સહ જાધોન', 'HusbandName': '', 'num': 129}
# ===
# ['[', 'શા]', '૪012508257', 'મતદારનું', 'નામ', ':', 'મંજુસિંહ', 'જાધોન', 'પિતાનું', 'નામ:', 'હ', 'ભાષસિહ', 'જાધોન', 'ઘર', 'નંબર', ':', 'સી-૩૬-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '41', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'મંજુસિંહ જાધોન', 'FatherName': 'હ ભાષસિહ', 'HusbandName': '', 'num': 130}
# ===
# ['[મ', '૫32]', '૪113919792', 'મતદારનું', 'નામ', ':', 'વૈશાલી', 'પંચસારા', 'પિતાનું', 'નામ:', 'ભૂપતી', 'ઘર', 'નંબર', ':', 'સી', 'બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '20', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'વૈશાલી પંચસારા', 'FatherName': 'ભૂપતી', 'HusbandName': '', 'num': 131}
# ===
# ['૪1013507779', 'મતદારનું', 'નામ', ':', 'બીરેન્દ્રકુમાર', 'શર્મા', 'પિતાનું', 'નામ:', 'શ્રી', 'કુકન', 'ઘર', 'નંબર', ':', 'સીહ', '-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '40', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'બીરેન્દ્રકુમાર શર્મા', 'FatherName': 'શ્રી કુકન', 'HusbandName': '', 'num': 132}
# ===
# ['૪013507811', 'મતદારનું', 'નામ', ':', 'રશ્મી', 'દેવી', 'શર્મા', 'પતિનું', 'નામ:', 'બીરેન્દ્ર', 'કુમાર', 'ઘર', 'નંબર', ':', 'સીકે', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '33', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'રશ્મી દેવી શર્મા', 'FatherName': '', 'HusbandName': 'બીરેન્દ્ર કુમાર', 'num': 133}
# ===
# ['મ', 'પડ', '0113700564', 'મતદારનું', 'નામ', ':', 'સત્યા', 'દ્રવિડ', 'પતિનું', 'નામ:', 'શંકર', 'ન', 'ઘર', 'નબર', ':', 'સી(૪ર/અ', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '23', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'સત્યા દ્રવિડ', 'FatherName': '', 'HusbandName': 'શંકર ન', 'num': 134}
# ===
# ['૪0૫3074309', 'મતદારનું', 'નામ', ':', 'સોનમ', 'ગોલંદાજ', 'પતિનું', 'નામ:', 'પ્રીતમસિંધ', 'ગોલંદાજ', 'ઘર', 'નંબર', ':', 'સી-૪૩-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '32', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'સોનમ ગોલંદાજ', 'FatherName': '', 'HusbandName': 'પ્રીતમસિંધ ગોલંદાજ', 'num': 135}
# ===
# ['૪003074317', 'મતદારનું', 'નામ', ':', 'અમીતકુમાર', 'ગીરી', 'પિતાનું', 'નામ:', 'અરૂણ', 'ગી', 'ઘર', 'નંબર', ':', 'સી-૪૫-બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '34', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'અમીતકુમાર ગીરી', 'FatherName': 'અરૂણ ગી', 'HusbandName': '', 'num': 136}
# ===
# ['0113918848', 'મતદારનું', 'નામ', ':', 'કાદરભાઈ', 'ગરણા', 'પિતાનું', 'નામ:', 'સુલેમાનભાઈ', 'ક', 'ઘર', 'નંબર', ':', 'સી/45એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '58', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'કાદરભાઈ ગરણા', 'FatherName': 'સુલેમાનભાઈ ક', 'HusbandName': '', 'num': 137}
# ===
# ['૪૫003902483', 'મતદારનું', 'નામ', ':', 'આયેશાબેન', 'ગરના', 'પતિનું', 'નામ:', 'કાદરભાઈ', 'ઘર', 'નંબર', ':', 'સ(45એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '55', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'આયેશાબેન ગરના', 'FatherName': '', 'HusbandName': 'કાદરભાઈ', 'num': 138}
# ===
# ['૪૫12785194', 'મતદારનું', 'નામ', ':', 'હર્ષદ', 'મકવાણા', 'પિતાનું', 'નામ:', 'બાબુભાઇ', 'મકવાણા', 'ઘર', 'નંબર', ':', 'સી-૪૬-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '35', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'હર્ષદ મકવાણા', 'FatherName': 'બાબુભાઇ મકવાણા', 'HusbandName': '', 'num': 139}
# ===
# ['૪1013022902', 'મતદારનું', 'નામ', ':', 'ચમનસિંહ', 'ચૌહાણ', 'પિતાનું', 'નામ:', 'ગાઢસિંહ્જી', 'ચૌહાણ', 'ઘર', 'નંબર', ':', 'સી', '-', '૫૦', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '85', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'ચમનસિંહ ચૌહાણ', 'FatherName': 'ગાઢસિંહ્જી ચૌહાણ', 'HusbandName': '', 'num': 140}
# ===
# ['0113022910', 'મતદારનું', 'નામ', ':', 'વસંતબા', 'ચૌહાણ', 'પતિનું', 'નામ:', 'ચમનસિંહ', 'ચૌહાણ', 'ઘર', 'નૅબર', ':', 'સી', '-', '૫૦', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '83', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'વસંતબા ચૌહાણ', 'FatherName': '', 'HusbandName': 'ચમનસિંહ ચૌહાણ', 'num': 141}
# ===
# ['૪1013022928', 'મતદારનું', 'નામ', ':', 'સત્યાવતી', 'જાટવ', 'પતિનું', 'નામ:', 'સસંહ', 'જાટવ', 'ઘર', 'નબર', ':', 'સૌ', '-', '૫૦', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '55', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'સત્યાવતી જાટવ', 'FatherName': '', 'HusbandName': 'સસંહ જાટવ', 'num': 142}
# ===
# ['૪૫13918802', 'મૃતદારનું', 'નામ', ':', 'મોહમ્મદ', 'આલોમ', 'પિતાનું', 'નામ:', 'તગ', 'પિમિ', 'ઘર', 'નંબર', ':', 'સી.14.', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '36', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'મોહમ્મદ આલોમ', 'FatherName': 'તગ પિમિ', 'HusbandName': '', 'num': 143}
# ===
# ['1113022803', 'મૃતદારનું', 'નામ', ':', 'સિતારામ', 'પ્રજાપતિ', 'પિતાનું', 'નામ:', 'જગદિશભાઇ', 'પ્રજાપતિ', 'ઘર', 'નંબર', ':', 'સી-૧૯-બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '36', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'સિતારામ પ્રજાપતિ', 'FatherName': 'જગદિશભાઇ પ્રજાપતિ', 'HusbandName': '', 'num': 144}
# ===
# ['0113508264', 'મતદારનું', 'નામ_:', 'દક્ષાબેન', 'પરમાર', 'પતિનું', 'નામ:', 'ગુપરભાઈ', 'ઘર', 'નૅબર', ':', 'સી', '39', 'એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '38', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'દક્ષાબેન પરમાર', 'FatherName': '', 'HusbandName': 'ગુપરભાઈ', 'num': 145}
# ===
# ['મતદારનું', 'નામ', ':', 'ભાવનાબેન', 'ચાવડા', 'પતિનું', 'નામ:', 'સંજયભાઈ', 'ઘર', 'નૅબર', ':', 'સી', '37', 'એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '33', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'ભાવનાબેન ચાવડા', 'FatherName': '', 'HusbandName': 'સંજયભાઈ', 'num': 146}
# ===
# ['૪013867785', 'મૂતદારનું', 'નામ', ':', 'નનબ,', 'મજેઠિયા', 'પેતાનું', 'નામ:', 'રાજુભા', 'ધર', 'નબર', 'ઃ', 'સૌતક/બ', 'બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '20', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'None', 'FatherName': '', 'HusbandName': '', 'num': 147}
# ===
# ['૪013510484', 'મતદારનું', 'નામ', ':', 'અફસાના', 'દલ', 'પિતાનું', 'નામ:', 'ઇકબાલભાઈ', 'ક', 'ઘર', 'નંબર', ':', 'સી', '55', 'એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '24', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'અફસાના દલ', 'FatherName': 'ઇકબાલભાઈ ક', 'HusbandName': '', 'num': 148}
# ===
# ['૪૫13918554', 'મતદારનું', 'નામ', ':', 'રાબીયા', 'દલ', 'પિતાનું', 'નામ:', 'ઇકબાલ', 'ઘર', 'નંબર', ':', 'સી.55એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '20', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'રાબીયા દલ', 'FatherName': 'ઇકબાલ', 'HusbandName': '', 'num': 149}
# ===
# interactive(children=(IntSlider(value=50, description='x', max=255, min=1), Output()), _dom_classes=('widget-i…
# ['|', '3]', '૪113457173', 'મતદારનું', 'નામ', 'હ', 'કન!', 'ન', 'જાં', 'પતિનું', 'નાંમ:', 'સંદીપકુમાર', "દેસા'", 'ઘર', 'નબર:', 'ક', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '35', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'મતદારનું નામ હ કન! ન જાં', 'FatherName': '', 'HusbandName': "સંદીપકુમાર દેસા'", 'num': 150}
# ===
# ['[*_', '382]', '૫3470986', 'મતદારનું', 'નામ', ':', 'દિવ્યા', 'વિરાજ', 'સેલારકા', 'સેલારકા', '%', 'પતિનું', 'નામ:', 'ધનજીભાઈ', 'તરપદા', 'ફોટો', 'ઉપલબ્ધ', 'ઘર', 'નબર', ':', 'સિ', 'ઉમર', ':', '25', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'દિવ્યા વિરાજ સેલારકા સેલારકા %', 'FatherName': '', 'HusbandName': 'ધનજીભાઈ તરપદા', 'num': 151}
# ===
# interactive(children=(IntSlider(value=50, description='x', max=255, min=1), Output()), _dom_classes=('widget-i…
# ['નમ', 'કો', '13279197', 'મતદારનું', 'નામ', ':', 'ચંદ્રિકા', 'માલકિયા', 'પતિનું', 'નામ:', 'દેવજીભાઇ', 'માલકિયા', 'ઘર', 'નંબર', ':', '1', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '27', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'ચંદ્રિકા માલકિયા', 'FatherName': '', 'HusbandName': 'દેવજીભાઇ માલકિયા', 'num': 152}
# ===
# ['₹પ1૩279189', 'મૃતદારનું', 'નામ', ':', 'પાર્થ', 'પોપટ', 'પિતાનું', 'નામ:', 'જિતેશભાઇ', 'પોપટ', 'ર', 'ઘર', 'નંબર', ':', '1', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '25', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'પાર્થ પોપટ', 'FatherName': 'જિતેશભાઇ પોપટ', 'HusbandName': '', 'num': 153}
# ===
# ['પો', '0૫13510450', 'મૃતદારનું', 'નામ', ':', 'નિકિતા', 'મિશ્રા', 'પિતાનું', 'નામ:', 'શિવપ્રસાદ', 'સિ', 'ઘર', 'નંબર', ':', '1', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '24', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'નિકિતા મિશ્રા', 'FatherName': 'શિવપ્રસાદ સિ', 'HusbandName': '', 'num': 154}
# ===
# ['7૫13603420', 'મતદારનું', 'નામ', ':', 'તમીલસેલવી', 'અદિદ્રવીડ', 'પતિનું', 'નામ:', 'રામૂ', 'ર', 'ઘર', 'નૅંબર', ':', '2', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '28', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'તમીલસેલવી અદિદ્રવીડ', 'FatherName': '', 'HusbandName': 'રામૂ ર', 'num': 155}
# ===
# ['(પ13507902', 'મૃતદારનું', 'નામ', ':', 'સંજય', 'રંગારી', 'પિતાનું', 'નામ:', 'નામદેવભાઈ', '%', 'ઘર', 'નંબર', ':', '3', 'એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '54', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'સંજય રંગારી', 'FatherName': 'નામદેવભાઈ %', 'HusbandName': '', 'num': 156}
# ===
# ['0૫13507936', 'મતદારનું', 'નામ', ':', 'અર્ચના', 'રંગારી', 'પતિનું', 'નામ:', 'સમ્યભાઈ', 'ઘર', 'નબર', ':', '3', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '45', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'અર્ચના રંગારી', 'FatherName': '', 'HusbandName': 'સમ્યભાઈ', 'num': 157}
# ===
# ['0112508273', 'મત્\u200cદારનું', 'નામ', 'ણં', 'રીટાબેન', 'સાગર', 'પતિનું', 'નામ:', 'વીરેન્દ્રકુમાર', 'સાગર', 'ઘર', 'નૅબર', ':', '૪-બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '47', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'મત્\u200cદારનું નામ ણં રીટાબેન સાગર', 'FatherName': '', 'HusbandName': 'વીરેન્દ્રકુમાર સાગર', 'num': 158}
# ===
# ['મતદારનું', 'નામ', ':', 'વિનોદકુમાર', 'પિતાનું', 'નામ:', 'રતનસિંહ', 'ઘર', 'નંબર', ':', '૫-બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '52', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'વિનોદકુમાર', 'FatherName': 'રતનસિંહ', 'HusbandName': '', 'num': 159}
# ===
# ['મતદારનું', 'નામ', ':', 'આશારાની', 'પતિનું', 'નામ:', 'વિનોદકુમાર', 'ર', 'ઘર', 'નબર', ':', '૫-બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '49', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'આશારાની', 'FatherName': '', 'HusbandName': 'વિનોદકુમાર ર', 'num': 160}
# ===
# ['7૫13900966', 'પતદાસનું', 'નામ', 'પિ', 'ગીજયસીહ', 'ચૌહાન', 'પેતાનું', 'નામ:', 'વિરેન્દ્રસીહ', 'ચૌહાન', 'ઘર', 'નંબર', ':', '5/બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '22', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'None', 'FatherName': '', 'HusbandName': '', 'num': 161}
# ===
# ['(૫3366150', 'મતદારનું', 'નામ', ':', 'અનિલકુમાર', 'બાગલા', 'પિતાનું', 'નામ:', 'કિશનસિંગ', 'બાગલા', 'ઘર', 'નંબર', ':', '૭-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '57', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'અનિલકુમાર બાગલા', 'FatherName': 'કિશનસિંગ બાગલા', 'HusbandName': '', 'num': 162}
# ===
# ['0013366176', 'મતદારનું', 'નામ', ':', 'ઈન્દ્રા', 'બાગલા', 'પતિનું', 'નામ:', 'અનિલકુમાર', 'બાગલા', 'ઘર', 'નબર', ':', '૭-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '53', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'ઈન્દ્રા બાગલા', 'FatherName': '', 'HusbandName': 'અનિલકુમાર બાગલા', 'num': 163}
# ===
# ['13366168', 'મતદારનું', 'નામ', ':', 'રાખી', 'બાગલા', 'પિતાનું', 'નામ:', 'અનિલકુમાર', 'બાગલા', 'ઘર', 'નંબર', ':', '૭-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '24', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'રાખી બાગલા', 'FatherName': 'અનિલકુમાર બાગલા', 'HusbandName': '', 'num': 164}
# ===
# ['૪1013932191', 'મતદારનું', 'નામ', ':', 'કરણ', 'ચૌહાન', 'પિતાનું', 'નામ:', 'અશોક', 'ચૌહાન', 'ઘર', 'નંબર', ':', '9/એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '19', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'કરણ ચૌહાન', 'FatherName': 'અશોક ચૌહાન', 'HusbandName': '', 'num': 165}
# ===
# ['0103913217', 'મતદારનું', 'નામ', ':', 'કાંતાબેન', 'મકવાણા', 'પતિનું', 'નામ:', 'જયપાલભાઈ', 'ન', 'ઘર', 'નંબર', ':', '10/બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '66', 'જાતે', ':', 'સ્ત્રી']
# ---
# {'Name': 'કાંતાબેન મકવાણા', 'FatherName': '', 'HusbandName': 'જયપાલભાઈ ન', 'num': 166}
# ===
# ['જા/[2785228', 'મતદારનું', 'નામ', ':', 'હીનાબા', 'જાડેજા', 'પિતાનું', 'નામ:', 'કિરીટસિંહ', 'જાડેજા', 'ઘર', 'નંબર', ':', '૧૦-બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '28', 'જાતિ', ':', 'સ્ત્રી']
# ---
# ...
# ---
# {'Name': 'બેબીકુમારી', 'FatherName': '', 'HusbandName': 'રવિન્દ્રકુમાર', 'num': 483}
# ===
# ['૪૫1૩074507', 'મતદારનું', 'નામ:', 'જા', 'રાજપુત', 'પિતાનું', 'નામ:', 'પુરસોત્તમ', 'રાજપુત', 'ઘર', 'નંબર', ':', 'સી૩એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '41', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'જા રાજપુત', 'FatherName': 'પુરસોત્તમ રાજપુત', 'HusbandName': '', 'num': 484}
# ===
# ['મતદારનું', 'નામ', ':', 'શબ્બીરશા', 'શાહમદાર', 'પિતાનું', 'નામ:', 'આહમદશા', 'શાહમદાર', 'ર', 'ઘર', 'નંબર', ':', 'સી-૪૪એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '40', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'શબ્બીરશા શાહમદાર', 'FatherName': 'આહમદશા શાહમદાર', 'HusbandName': '', 'num': 485}
# ===
# ['મતદારનું', 'નામ', ':', 'નસીમ', 'શાહમદાર', 'પતિનું', 'નામ:', 'શબ્બીરશા', 'શાહમદાર', 'જ', 'ઘર', 'નંબર', ':', 'સી-૪૪એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '37', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'નસીમ શાહમદાર', 'FatherName': '', 'HusbandName': 'શબ્બીરશા શાહમદાર', 'num': 486}
# ===
# ['0013074515', 'મતદારનું', 'નામ', ':', 'શિલ્પા', 'જોગડીયા', 'પતિનું', 'નામ:', 'પરેશભાઇ', 'જોગડીયા', 'ઘર', 'નૅબર', ':', 'સી-૪૮', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '34', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'શિલ્પા જોગડીયા', 'FatherName': '', 'HusbandName': 'પરેશભાઇ જોગડીયા', 'num': 487}
# ===
# ['૪013507597', 'મતદારનું', 'ખામ', ':', 'શીતલ', 'ગરિયા', 'અન્ય:', 'ગોકળભાઈ', 'ઘર', 'નંબર', ':', 'સી', '26', 'બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '34', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'None', 'FatherName': '', 'HusbandName': '', 'num': 488}
# ===
# ['૪0૫3150182', 'મતદારનું', 'નામ', ':', 'રૂકસાર', 'દલ', 'પતિનું', 'નામ:', 'અશરફભાઇ', 'દલ', 'ઘર', 'નબર', ':', 'સી૩પ-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '29', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'રૂકસાર દલ', 'FatherName': '', 'HusbandName': 'અશરફભાઇ દલ', 'num': 489}
# ===
# ['રળટ508372', 'મતદારનું', 'નામ', ':', 'બાલસુંદરી', 'ડ્વીડ', 'પતિનું', 'નામ:', 'બાલમુર્ગન', 'ડ્વીડ', 'ર', 'ઘર', 'નંબર', ':', 'ઈ-', 'દહ', 'ફોટો', 'ઉપધબ્લ', 'ઉમર', ':', '31', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'બાલસુંદરી ડ્વીડ', 'FatherName': '', 'HusbandName': 'બાલમુર્ગન ડ્વીડ', 'num': 490}
# ===
# ['પતદાસનું', 'નામ', 'પિ', 'ભાલમુર્ગત', 'ડ્વીડ', 'પેતાનું', 'નામ:', 'વિટ્ટીવેલ', 'ડ્વીડ', 'ઘર', 'નંબર', ':', 'ઇ-દ9', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '35', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'None', 'FatherName': '', 'HusbandName': '', 'num': 491}
# ===
# ['[/012521359', 'મતદારનું', 'નામ', ':', 'હેતલબેન', 'શાહ', 'પતિનું', 'નામ:', 'સંજયકુમાર', 'ઘર', 'ર', ':', 'ક્વાટર', 'નૅ', '14', 'બી', 'ટાઈપ', '2', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '42', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'હેતલબેન શાહ', 'FatherName': '', 'HusbandName': 'સંજયકુમાર', 'num': 492}
# ===
# ['0172521342', 'મતદારનું', 'નામ', ':', 'સંજયકુમાર', 'શાહ', 'પિતાનું', 'નામ:', 'પ્રવિનચંદ્ર', 'ઘર', 'નંબર', ':', 'કવાટર', 'નં', '14', 'બી', 'ટાઈપ', '2', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '41', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'સંજયકુમાર શાહ', 'FatherName': 'પ્રવિનચંદ્ર', 'HusbandName': '', 'num': 493}
# ===
# ['0113976354', 'મતદારનું', 'નામ', ':', 'જય', 'પરમાર', 'માતાનું', 'નામ;', 'દક્ષાબેન', 'ઘર', 'નંબર', ':', 'રૅલરવ', 'લોકો', 'કાલોની', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '19', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'None', 'FatherName': '', 'HusbandName': '', 'num': 494}
# ===
# ['૪013972908', 'મતદારનું', 'નામ', ':', 'તાન્યા', 'શાહુલ', 'પિતાનું', 'નામ;', 'નૌશાદ', 'ઘર', 'નંબર', ':', 'રલવૈ', 'કવાર્ટર', '19/બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '25', 'જાતિ', ':', 'રસ્ત્ર']
# ---
# {'Name': 'તાન્યા શાહુલ', 'FatherName': 'નૌશાદ', 'HusbandName': '', 'num': 495}
# ===
# interactive(children=(IntSlider(value=50, description='x', max=255, min=1), Output()), _dom_classes=('widget-i…
# ['મૃતદારનું', 'નામ', ':', 'દિનેશભાઈ', 'યાદવ', 'પિતાનું', 'નામ:', 'રામનિવાસભાઈ', 'યાદવ', 'ઘર', 'નંબર', ':', '૧૦૪-બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '41', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'દિનેશભાઈ યાદવ', 'FatherName': 'રામનિવાસભાઈ યાદવ', 'HusbandName': '', 'num': 496}
# ===
# ['૪1012785756', 'મતદારનું', 'નામ', ':', 'રાજકુમારી', 'યાદવ', 'પતિનું', 'નામ:', 'દિનેશભાઈ', 'યાદવ', 'ઘર', 'નૅબર', ':', '૧૦૪-બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '39', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'રાજકુમારી યાદવ', 'FatherName': '', 'HusbandName': 'દિનેશભાઈ યાદવ', 'num': 497}
# ===
# ['૪102489326', 'મૃતદારનું', 'નામ', ':', 'રણછોડ', 'મેર', 'પિતાનું', 'નામ:', 'પ્રભુભાઇ', 'મેર', 'ક', 'ઘર', 'નંબર', ':', '૧રર-બી-ઇ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '30', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'રણછોડ મેર', 'FatherName': 'પ્રભુભાઇ મેર', 'HusbandName': '', 'num': 498}
# ===
# ['૪013279254', 'મૃતદારનું', 'નામ', ':', 'હાર્દિક', 'ચૌહાણ', 'પિતાનું', 'નામ:', 'અશોકભાઇ', 'ચૌહાણ', '.', 'ઘર', 'નંબર', ':', '198', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '25', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'હાર્દિક ચૌહાણ', 'FatherName': 'અશોકભાઇ ચૌહાણ', 'HusbandName': '', 'num': 499}
# ===
# ['મતદારનું', 'નામ', ':', 'મયુરકુમાર', 'ગોંડલીયા', 'પિતાનું', 'નામ:', 'બાબુલાલ', 'ગોંડલીયા', 'ઘર', 'નંબર', ':', '262-એ', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '30', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'મયુરકુમાર ગોંડલીયા', 'FatherName': 'બાબુલાલ ગોંડલીયા', 'HusbandName': '', 'num': 500}
# ===
# ['ઉ૫૫૮5272547', 'મૃતદારનું', 'નામ', ':', 'વીપુલભાઇ', 'લીંબડીયા', 'પિતાનું', 'નામ:', 'દેવજીભાઇ', 'લીંબડીયા', ',', 'ઘર', 'નંબર', ':', '265', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '35', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'વીપુલભાઇ લીંબડીયા', 'FatherName': 'દેવજીભાઇ લીંબડીયા', 'HusbandName': '', 'num': 501}
# ===
# ['ઊ।/04/018/072183', 'તૂતદારનું', 'નામ', 'નનન', 'રાણા', 'પિતાનું', 'નામ:', 'ભીખુભા', 'રાણા', 'ઘર', 'પર', 'ન', '27૩', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '65', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'તૂતદારનું નામ નનન રાણા', 'FatherName': 'ભીખુભા રાણા', 'HusbandName': '', 'num': 502}
# ===
# ['ઊ[/04/018/072184', 'મતદારનું', 'નામ', ':', 'હર્ષાબા', 'રાણા', 'પતિનું', 'નામ:', 'પ્રવીણસીહ', 'રાણા', 'ઘર', 'નબર', ':', '273', 'ઉમર', ':', '60', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'હર્ષાબા રાણા', 'FatherName': '', 'HusbandName': 'પ્રવીણસીહ રાણા', 'num': 503}
# ===
# ['૯૫૮4826384', 'મતદારનું', 'નામ', ':', 'મયુરીબા', 'રાણા', 'પિતાનું', 'નામ:', 'પ્રવીણસીહ', 'રાણા', 'ન', 'ઘર', 'નંબર', ':', '273', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '35', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'મયુરીબા રાણા', 'FatherName': 'પ્રવીણસીહ રાણા', 'HusbandName': '', 'num': 504}
# ===
# ['ઊ।/04/018/072210', 'મતદારનું', 'નામ', ':', 'ગગજીભાઇ', 'પરમાર', 'પિતાનું', 'નામ:', 'અરજણભાઇ', 'પરમાર', 'ઘર', 'નંબર', ':', '274', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '73', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'ગગજીભાઇ પરમાર', 'FatherName': 'અરજણભાઇ પરમાર', 'HusbandName': '', 'num': 505}
# ===
# ['ઊ।/04/018/072226', 'મતદારનું', 'નામ', ':', 'હીનાબેન', 'પરમાર', 'પતિનું', 'નામ:', 'ગગજીભાઇ', 'પરમાર', 'ઘર', 'નંબર', ':', '274', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '67', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'હીનાબેન પરમાર', 'FatherName': '', 'HusbandName': 'ગગજીભાઇ પરમાર', 'num': 506}
# ===
# ['૯૫૮1696160', 'મતદારનું', 'નામ', ':', 'રાજેન્દ્રભાઇ', 'પંડયા', 'પિતાનું', 'નામ:', 'સુખદવભાઈ', 'પંડયા', 'ઘર', 'નંબર', ':', '281', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '62', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'રાજેન્દ્રભાઇ પંડયા', 'FatherName': 'સુખદવભાઈ પંડયા', 'HusbandName': '', 'num': 507}
# ===
# ['મતદારનું', 'નામ', ':', 'ગંગાબેન', 'પંડયા', 'પતિનું', 'નામ:', 'રાજેન્દ્રભાઇ', 'પંડયા', 'ઘર', 'નંબર', ':', '281', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '52', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'ગંગાબેન પંડયા', 'FatherName': '', 'HusbandName': 'રાજેન્દ્રભાઇ પંડયા', 'num': 508}
# ===
# ['6૫૫૮૩625936', 'મતદારનું', 'નામ', ':', 'દેવરાજભાઇ', 'ગઢવી', 'પિતાનું', 'નામ:', 'પાલાભાઇ', 'ગઢવી', 'ઘર', 'નબર', ':', 'ટકે', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '62', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'દેવરાજભાઇ ગઢવી', 'FatherName': 'પાલાભાઇ ગઢવી', 'HusbandName': '', 'num': 509}
# ===
# ['મ', 'કપ', '6૫૮3625944', 'મતદારનું', 'નામ', ':', 'જશુબેન', 'ગઢવી', 'પતિનું', 'નામ:', 'દેવરાજભાઇ', 'ગઢવી', 'ન', 'ઘર', 'નંબર', ':', 'ટકે', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '57', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'જશુબેન ગઢવી', 'FatherName': '', 'HusbandName': 'દેવરાજભાઇ ગઢવી', 'num': 510}
# ===
# ['[મ', '512]', '૫૫૦4907606', 'મતદારનું', 'નામ', ':', 'કાજલબેન', 'ગઢવી', 'પિતાનું', 'નામ:', 'દેવરાજભાઇ', 'ગઢવી', 'ઘર', 'નબર', ':', '283', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '36', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'કાજલબેન ગઢવી', 'FatherName': 'દેવરાજભાઇ ગઢવી', 'HusbandName': '', 'num': 511}
# ===
# ['[મ', '53]', '૪012489359', 'મતદારનું', 'નામ', ':', 'રાજલ', 'ફુનડા', 'પિતાનું', 'નામ:', 'દેવરાજભાઈ', 'કુનડા', 'ઘર', 'નબર', ':', 'ર૮૩', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '33', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'રાજલ ફુનડા', 'FatherName': 'દેવરાજભાઈ કુનડા', 'HusbandName': '', 'num': 512}
# ===
# ['101234333૩', 'મૂતદારનું', 'નામ', ':', 'તેજલ', 'ફુનડા', 'પિતાનું', 'નામ:', 'દેવરાજભાઈ', 'કુનડા', 'ક', 'ઘર', 'નંબર', ':', '283', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '31', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'તેજલ ફુનડા', 'FatherName': 'દેવરાજભાઈ કુનડા', 'HusbandName': '', 'num': 513}
# ===
# ['[|', 'કાડ]', '૪2489342', 'મતદારનું', 'નામ', ':', 'ઉર્વશી', 'કુડા', 'પિતાનું', 'નામ:', 'દેવરાજભાઈ', 'ફુનડા', 'ઘર', 'નબર', ':', '૨૮૩', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '30', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'ઉર્વશી કુડા', 'FatherName': 'દેવરાજભાઈ ફુનડા', 'HusbandName': '', 'num': 514}
# ===
# ['૪1012785764', 'મતદારનું', 'નામ', ':', 'સંપુર્ણા', 'ફનડા', 'પિતાનું', 'નામ:', 'દેવરાજભાઈ', 'કુનડા', 'ઘર', 'નબર', ':', 'ર૮૩', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '27', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'સંપુર્ણા ફનડા', 'FatherName': 'દેવરાજભાઈ કુનડા', 'HusbandName': '', 'num': 515}
# ===
# ['૯૫૮48૩4156', 'મતદારનું', 'નામ', ':', 'ચંદ્રાબેન', 'પંડીત', 'પતિનું', 'નામ:', 'વીસ્વલીગમ', 'પંડીત', 'ક', 'ઘર', 'નૅબર', ':', '286', 'ફોટો', 'ઉપલબ્ધ', 'ઉંમર', ':', '65', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'ચંદ્રાબેન પંડીત', 'FatherName': '', 'HusbandName': 'વીસ્વલીગમ પંડીત', 'num': 516}
# ===
# ['6૫૫૮5272554', 'મૃતદારનું', 'નામ', ':', 'વેલમરગન', 'પંડીત', 'પિતાનું', 'નામ:', 'વીસ્વલીંગમ', 'પંડીત', 'ઘર', 'નબર', ':', '286', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '48', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'વેલમરગન પંડીત', 'FatherName': 'વીસ્વલીંગમ પંડીત', 'HusbandName': '', 'num': 517}
# ===
# ['૦૫૦4832366', 'મતદારનું', 'નામ', ':', 'કોલજીનાદત', 'પંડીત', 'પિતાનું', 'નામ:', 'વીસ્વલીગમ', 'પંડીત', 'ઘર', 'નબર', ':', '286', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '42', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'કોલજીનાદત પંડીત', 'FatherName': 'વીસ્વલીગમ પંડીત', 'HusbandName': '', 'num': 518}
# ===
# ['(૫3366218', 'મતદારનું', 'નામ:', 'વસન્તીબેન', 'પંડિત', 'પતિનું', 'નામ:', 'કોલજીનાદન', 'પંડિત', 'જ', 'ઘર', 'નબર', ':', 'ર૮ડ્\u200c', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '30', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'વસન્તીબેન પંડિત', 'FatherName': '', 'HusbandName': 'કોલજીનાદન પંડિત', 'num': 519}
# ===
# ['|', 'ક', 'ઉમતડ842885', 'મતદારનું', 'નામ', ':', 'બાબુલાલ', 'પરમાર', 'પિતાનું', 'નામ:', 'હીરાભાઇ', 'પરમાર', 'ઘર', 'નંબર', ':', '287', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '59', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'બાબુલાલ પરમાર', 'FatherName': 'હીરાભાઇ પરમાર', 'HusbandName': '', 'num': 520}
# ===
# ['મતદારનું', 'નામ', ':', 'સંજયભાઇ', 'પરમાર', 'પિતાનું', 'નામ:', 'બાબુલાલ', 'પરમાર', 'કે', 'ઘર', 'નંબર', ':', '287', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '35', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'સંજયભાઇ પરમાર', 'FatherName': 'બાબુલાલ પરમાર', 'HusbandName': '', 'num': 521}
# ===
# ['મતદારનું', 'નામ', ':', 'હંસાબેન', 'પરમાર', 'પતિનું', 'નામ:', 'બાબુલાલ', 'પરમાર', 'કિમિ', 'ઘર', 'નૅબર', ':', '287', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '52', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'હંસાબેન પરમાર', 'FatherName': '', 'HusbandName': 'બાબુલાલ પરમાર', 'num': 522}
# ===
# ['મતદારનું', 'નામ', ':', 'સુરજ', 'પરમાર', 'પિતાનું', 'નામ:', 'બાબુભાઇ', 'પરમાર', 'ઘર', 'નંબર', ':', '૨૮૭', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '30', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'સુરજ પરમાર', 'FatherName': 'બાબુભાઇ પરમાર', 'HusbandName': '', 'num': 523}
# ===
# ['મતદારનું', 'નામ', ';', 'મૃણાનંદમ', 'મદ્રાસી', 'પિતાનું', 'નામ:', 'સીગારામ', 'મદ્રાર્સ', 'ક', 'ઘર', 'નંબર', ':', '291', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '47', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'મૃણાનંદમ મદ્રાસી', 'FatherName': 'સીગારામ મદ્રાર્સ', 'HusbandName': '', 'num': 524}
# ===
# ['૪012076644', 'મતદારનું', 'નામ', ':', 'રાધાબેન', 'મદ્રાસી', 'પતિનું', 'નામ:', 'મૂણાનંદમ', 'મદ્રાર્સ', 'ન', 'ઘર', 'નૅબર', ':', '291', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '42', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'રાધાબેન મદ્રાસી', 'FatherName': '', 'HusbandName': 'મૂણાનંદમ મદ્રાર્સ', 'num': 525}
# ===
# interactive(children=(IntSlider(value=50, description='x', max=255, min=1), Output()), _dom_classes=('widget-i…
# ['ઊ/04/018/072205', 'મૃતદારનું', 'નામ', ':', 'તંગરાજ', 'આદીવીડર', 'પિતાનું', 'નામ:', 'મીજાસ્વામી', 'આદીવીડર', 'ઘર', 'નંબર', ':', '296', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '65', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'તંગરાજ આદીવીડર', 'FatherName': 'મીજાસ્વામી આદીવીડર', 'HusbandName': '', 'num': 526}
# ===
# ['લ/04/018/072137', 'મતદારનું', 'નામ', ':', 'સરોજા', 'આદીવીડર', 'પતિનું', 'નામ:', 'તંગરાજ', 'આદીવીડર', 'ઘર', 'નબર', ':', '296', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '63', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'સરોજા આદીવીડર', 'FatherName': '', 'HusbandName': 'તંગરાજ આદીવીડર', 'num': 527}
# ===
# ['મૃતદારનું', 'નામ', ':', 'હરીકૃષ્ણન', 'આદીવીડર', 'પિતાનું', 'નામ:', 'તંગરાજ', 'આદીવીડર', 'બિ', 'ઘર', 'નંબર', ':', '296', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '36', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'હરીકૃષ્ણન આદીવીડર', 'FatherName': 'તંગરાજ આદીવીડર', 'HusbandName': '', 'num': 528}
# ===
# ['ઊ।/04/018/072135', 'મતદારનું', 'નામ', ':', 'રાજમણીકમ', 'આદીવેડર', 'ર', 'પિતાનું', 'નામ:', 'મુરતન', 'આદીવીડર', 'ફોટો', 'ઉપલબ્ધ', 'ઘર', 'નબર', ':', '2', 'ઉંમર', ':', '59', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'રાજમણીકમ આદીવેડર ર', 'FatherName': 'મુરતન આદીવીડર', 'HusbandName': '', 'num': 529}
# ===
# ['|]', 'ક]', 'ઊ|/04/018/072136', 'મતદારનું', 'નામ', ':', 'કોલનજીન', 'આદીવીડર', 'ન', 'પતિનું', 'નામ:', 'રાજમણીકમ', 'આદીવીડર', 'ફોટો', 'ઉપલબ્ધ', 'ઘર', 'નંબર', ':', 'ક', 'ઉંમર', ':', '52', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'કોલનજીન આદીવીડર ન', 'FatherName': '', 'HusbandName': 'રાજમણીકમ આદીવીડર', 'num': 530}
# ===
# ['યો', 'ઉ૫૫૮3733359', 'મતદારનું', 'નામ', ':', 'રવી', 'આદીવીડર', 'પિતાનું', 'નામ:', 'રાજમણીકમ', 'આદીવીડર', 'ન', 'ઘર', 'નંબર', ':', '297', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '35', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'રવી આદીવીડર', 'FatherName': 'રાજમણીકમ આદીવીડર', 'HusbandName': '', 'num': 531}
# ===
# ['[મ', '53]', '0012940260', 'મતદારનું', 'નામ', ':', 'ભાનૃપ્રિયા', 'આદીવીડર', 'પતિનું', 'નામ:', 'રવિભાઇ', 'આદીવીડર', 'ઘર', 'નૅબર', ':', '297', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '34', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'ભાનૃપ્રિયા આદીવીડર', 'FatherName': '', 'HusbandName': 'રવિભાઇ આદીવીડર', 'num': 532}
# ===
# ['01012489367', 'મતદારનું', 'નામ', ':', 'રામુ', 'આદીદ્રાવીણા', 'પિતાનું', 'નામ:', 'રાજમણીકમ', 'આદીદ્રાવીણા', '[|', '__', 'ઘર', 'નંબર', ':', '૨૯૭', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '30', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'રામુ આદીદ્રાવીણા', 'FatherName': 'રાજમણીકમ આદીદ્રાવીણા', 'HusbandName': '', 'num': 533}
# ===
# ['[', '535]', '૪૫10843987', 'મતદારનું', 'નામ', ':', 'જગદીશભાઇ', 'ર', 'પિતાનું', 'નામ:', 'ભગવાનભાઇ', 'ગુ', 'ર', 'ઘર', 'નંબર', ':', '299', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '59', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'જગદીશભાઇ ર', 'FatherName': 'ભગવાનભાઇ ગુ', 'HusbandName': '', 'num': 534}
# ===
# interactive(children=(IntSlider(value=50, description='x', max=255, min=1), Output()), _dom_classes=('widget-i…
# ['રા', '1571620822', 'મતદારનું', 'નામ', ':', 'વસંતભાઇ', 'સોનગ્રા', 'પિતાનું', 'નામ:', 'છગનભાઇ', 'સોનગ્રા', 'ઘર', 'નંબર', ':', 'ત્ય્પે-3-8/બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '54', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'વસંતભાઇ સોનગ્રા', 'FatherName': 'છગનભાઇ સોનગ્રા', 'HusbandName': '', 'num': 535}
# ===
# ['|', '2', '1571620764', 'મતદારનું', 'નામ', ':', 'શારદાબેન', 'સોનગ્રા', 'પતિનું', 'નામ:', 'વસંતભાઇ', 'સોનગ્રા', 'મિ', 'ઘર', 'નબર', ':', 'ટાઈપ', '-3', '-', '8/બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '54', 'જાતિ', ':', 'સ્ત્રી']
# ---
# {'Name': 'શારદાબેન સોનગ્રા', 'FatherName': '', 'HusbandName': 'વસંતભાઇ સોનગ્રા', 'num': 536}
# ===
# ['દા', '22145092', 'મતદારનું', 'નામ', ':', 'દેવેન્દ્ર', 'સોનગરા', 'પિતાનું', 'નામ:', 'વસંતભાઇ', 'સોનાગ્રા', 'પિ', 'ઘર', 'નંબર', ':', 'ટાઈપ', '3', '-', '8/બી', 'ફોટો', 'ઉપલબ્ધ', 'ઉમર', ':', '26', 'જાતિ', ':', 'પુરુષ']
# ---
# {'Name': 'દેવેન્દ્ર સોનગરા', 'FatherName': 'વસંતભાઇ સોનાગ્રા', 'HusbandName': '', 'num': 537}
# ===
# 101 completed
# ===
# end
